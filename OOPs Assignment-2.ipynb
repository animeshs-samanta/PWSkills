# %% [markdown]
# -------------------------------------- Constructor: ------------------------------

# %% [raw]
# #1. What is a constructor in Python? Explain its purpose and usage.
#
# Constructors are generally used for instantiating an object. The task of constructors is to initialize(assign values) to the data members
# of the class when an object of the class is created. In Python the __init__() method is called the constructor and is always called when
# an object is created.
#
# Syntax of constructor declaration :
#
# def __init__(self):
#     # body of the constructor
#
# Initialization of objects: Constructors are used to initialize the objects of a class. They allow you to set default values for attributes or properties, and also allow you to initialize the object with custom data.
#
# Easy to implement: Constructors are easy to implement in Python, and can be defined using the __init__() method.
#
# Better readability: Constructors improve the readability of the code by making it clear what values are being initialized and how they are being initialized.
#
# Encapsulation: Constructors can be used to enforce encapsulation, by ensuring that the object’s attributes are initialized correctly and in a controlled manner.

# %% [raw]
# #2. Differentiate between a parameterless constructor and a parameterized constructor in Python.
#
# 1. Parameterless Constructor:
#
# A parameterless constructor is a constructor that takes no parameters.
# It is also known as the default constructor or the no-argument constructor.
# It is defined without any parameters in the constructor method.
# Its purpose is to initialize the object with default values or perform any necessary setup without requiring any external input.
#
# 2. Parameterized Constructor:
#
# A parameterized constructor is a constructor that takes one or more parameters.
# It allows you to initialize the object with specific values provided during the object creation.
# It takes parameters within the parentheses of the "__init__" method.
# The values passed as parameters are used to set the initial state of the object.

# %%
#3#. How do you define a constructor in a Python class? Provide an example.

'''
Syntax of constructor declaration : 

def __init__(self):
    # body of the constructor
'''

class myclass:
	def __init__(self):
		self.var = "Animesh"

	def print_value(self):
		print(self.var)
        
obj = myclass()

obj.print_value()
# Out:
# Animesh

# %% [raw]
# #4. Explain the `__init__` method in Python and its role in constructors.
#
# In Python, __init__ is a special method known as the constructor. It is automatically called when a new instance (object) of a
# class is created. The __init__ method allows you to initialize the attributes (variables) of an object.

# %%
#5. In a class named `Person`, create a constructor that initializes the `name` and `age` attributes. Provide an 
# example of creating an object of this class.

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def print_value(self):
        print(self.name)
        print(self.age)
obj = Person("Animesh", 22)

obj.print_value()
# Out:
# Animesh
# 22

# %%
# 6. How can you call a constructor explicitly in Python? Give an example.

'''
In Python, constructors are typically called implicitly when an object is created using the class name and parentheses. However,
if you want to call a constructor explicitly, you can do so by using the `__init__` method of the class. Here's an example:
'''

class MyClass:
    def __init__(self, value):
        self.my_variable = value
        print("Constructor called with value:", value)

# Explicitly calling the constructor
obj = MyClass.__init__(MyClass(), 42)

'''
In this example, `MyClass.__init__(MyClass(), 42)` explicitly calls the constructor of the `MyClass` class with the argument `42`. 
However, it's important to note that explicitly calling the constructor in this manner is uncommon and not the typical way of creating 
objects in Python. The constructor is usually called implicitly when you create an object using the class name:
'''

# %%
# 7. What is the significance of the `self` parameter in Python constructors? Explain with an example.
'''
The self is used to represent the instance of the class. With this keyword, you can access the attributes and methods of the class in python.
It binds the attributes with the given arguments.
'''
class myclass:
	def __init__(self):
		self.var = "Animesh"

	def print_value(self):
		print(self.var)

obj = myclass()

obj.print_value()
# Out:
# Animesh

# %% [markdown]
# # 8. Discuss the concept of default constructors in Python. When are they used?
#
# Default Constructor: A default constructor is a constructor that takes no arguments. It is used to create an object with default values
# for its attributes.

# %%
#9. Create a Python class called `Rectangle` with a constructor that initializes the `width` and `height` attributes. P
# rovide a method to calculate the area of the rectangle.

class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height
        
    def Area(self):
        print("Area of rectangle is : ", self.width*self.height)
        
obj = Rectangle(5,10)
obj.Area()
# Out:
# Area of rectangle is :  50

# %%
# 10. How can you have multiple constructors in a Python class? Explain with an example.

'''
Python does not support explicit multiple constructors, yet there are some ways using which multiple constructors can be achieved.
If multiple __init__ methods are written for the same class, then the latest one overwrites all the previous constructors and the 
reason for this can be, python stores all the function names in a class as key in a dictionary so, when a new function is defined 
with the same name, the key remains the same but the value gets overridden by the new function body.
'''
class example:

	def __init__(self):
		print("One")

	def __init__(self):
		print("Two")

	def __init__(self):
		print("Three")

e = example()
# Out:
# Three

# %%
# 11. What is method overloading, and how is it related to constructors in Python?
'''
Two or more methods have the same name but different numbers of parameters or different types of parameters, or both. These methods are
called overloaded methods and this is called method overloading. 
'''

# %%
# 12. Explain the use of the `super()` function in Python constructors. Provide an example.

'''
In Python, the super() function is used to refer to the parent class or superclass. It allows you to call methods defined in the superclass
from the subclass, enabling you to extend and customize the functionality inherited from the parent class.
'''
class Emp():
	def __init__(self, id, name, Add):
		self.id = id
		self.name = name
		self.Add = Add

# Class freelancer inherits EMP
class Freelance(Emp):
	def __init__(self, id, name, Add, Emails):
		super().__init__(id, name, Add)
		self.Emails = Emails

Emp_1 = Freelance(103, "Suraj kr gupta", "Noida" , "KKK@gmails")
print('The ID is:', Emp_1.id)
print('The Name is:', Emp_1.name)
print('The Address is:', Emp_1.Add)
print('The Emails is:', Emp_1.Emails)

'''
In the given example, The Emp class has an __init__ method that initializes the id, and name and Adds attributes. The Freelance class inherits
from the Emp class and adds an additional attribute called Emails. It calls the parent class’s __init__ method super() to initialize the inherited 
attribute.
'''
# Out:
# The ID is: 103
# The Name is: Suraj kr gupta
# The Address is: Noida
# The Emails is: KKK@gmails
# '\nIn the given example, The Emp class has an __init__ method that initializes the id, and name and Adds attributes. The Freelance class inherits\nfrom the Emp class and adds an additional attribute called Emails. It calls the parent class’s __init__ method super() to initialize the inherited \nattribute.\n'

# %%
# 13. Create a class called `Book` with a constructor that initializes the `title`, `author`, and `published_year` attributes.
# Provide a method to display book details.

class Book:
    def __init__(self, title, author, published_year):
        self.title = title
        self.author = author
        self.published_year = published_year

    def display_details(self):
        print(f"Title: {self.title}")
        print(f"Author: {self.author}")
        print(f"Published Year: {self.published_year}")

book1 = Book("SandhyaTara", "J.D. sen", 1951)
book1.display_details()
# Out:
# Title: SandhyaTara
# Author: J.D. sen
# Published Year: 1951

# %%
# 14. Discuss the differences between constructors and regular methods in Python classes.

              Constructor                                                          	Method
1.	A constructor initializes an object.	                          A method is a set of instructions that returns a value after execution.
2.	The 'new' keyword is crucial for calling the constructor.	      Method calls are essential for invoking methods.
3.	It lacks a return type.	                                          It has a return type.
4.	The constructor and class always have identical names.	          Methods can bear any name.
5.	A constructor initializes an object that doesn't exist yet.	      A method operates on objects that have already been created.
6.	A class can have multiple constructors with varying parameters.	  A class can have numerous methods with different parameters.
7.	It can't be inherited by subclasses.	                          It can be inherited by subclasse

# %%
# 15. Explain the role of the `self` parameter in instance variable initialization within a constructor.

'''
The self is used to represent the instance of the class. With this keyword, you can access the attributes and methods of the class in python.
It binds the attributes with the given arguments.
'''
class myclass:
	def __init__(self):
		self.var = "Animesh"
	def print_value(self):
		print(self.var)
obj = myclass()
obj.print_value()
# Out:
# Animesh

# %%
# 16. How do you prevent a class from having multiple instances by using constructors in Python? Provide anexample.
'''
In Python, you can prevent a class from having multiple instances by using a class variable to track whether an instance has already been created. 
Here's an example using a technique often referred to as a "singleton" pattern:
'''
class SingletonClass:
    _instance = None 

    def __new__(cls, *args, **kwargs):
        if not cls._instance:
            # If an instance doesn't exist, create one
            cls._instance = super().__new__(cls)
        return cls._instance

    def __init__(self, data):
        # This will be called only if the instance is newly created
        if not hasattr(self, 'initialized'):
            self.data = data
            self.initialized = True

singleton1 = SingletonClass("Instance 1")
print(singleton1.data)

singleton2 = SingletonClass("Instance 2")
print(singleton2.data)

# Both instances refer to the same object
print(singleton1 is singleton2)
# Out:
# Instance 1
# Instance 1
# True

# %%
# 17. Create a Python class called `Student` with a constructor that takes a list of subjects as a parameter and initializes the `subjects` attribute.

class Student:
    def __init__(self, subjects):
        self.subjects = subjects
        
    def display_subjects(self):
        print("Subjects ")
        for subject in self.subjects:
            print(f" - {subject}")

sub  = Student(["DSA", "Python","Java","DBMS"])
sub.display_subjects()
# Out:
# Subjects
#  - DSA
#  - Python
#  - Java
#  - DBMS

# %%
# 18. What is the purpose of the `__del__` method in Python classes, and how does it relate to constructors?
'''
The __del__ method in Python classes is a special method that is called when an object is about to be destroyed, i.e., when there are no more
references to the object. It serves as the destructor for a class, allowing you to define the cleanup actions that should be performed before 
the object is deleted and its memory is released.
'''
class MyClass:
    def __init__(self, name):
        self.name = name
        print(f"{self.name} is created.")

    def __del__(self):
        print(f"{self.name} is about to be destroyed.")

obj = MyClass("Object")

# Deleting the object explicitly
del obj
# Out:
# Object is created.
# Object is about to be destroyed.

# %%
# 19. Explain the use of constructor chaining in Python. Provide a practical example.

# %%
# 20. Create a Python class called `Car` with a default constructor that initializes the `make` and `model` attributes.
# Provide a method to display car information.

class Car:
    def __init__(self, make, model):
        self.make = make
        self.model = model
        
    def display_information(self):
        print("Car Information")
        print(self.make, self.model)
        
    
c1  = Car("23/11/2001\n", "Hero")
c1.display_information()
# Out:
# Car Information
# 23/11/2001
#  Hero

# %% [markdown]
# ------------------------------------------ Inheritance: --------------------------------------------------

# %%
# 1. What is inheritance in Python? Explain its significance in object-oriented programming.

Inheritance is a fundamental concept in object-oriented programming (OOP) and is supported by many programming languages, including Python. 
It allows a new class, called a subclass or derived class, to inherit attributes and methods from an existing class, known as a superclass 
or base class. This mechanism promotes code reuse and the creation of a hierarchical structure in which classes share common characteristics.

The syntax looks like this:
    
class BaseClass:
    # Some attributes and methods

class DerivedClass(BaseClass):
    # Additional attributes and methods
Significance of Inheritance in Object-Oriented Programming:
    Code Reusability:
    Hierarchical Structure
    Polymorphism
    Maintenance and Updates
    Encapsulation

# %%
# 2. Differentiate between single inheritance and multiple inheritance in Python. Provide examples for each.
'''
Single Inheritance:
Single inheritance occurs when a class inherits from only one base class. The subclass inherits the attributes and methods of the single base class. 
This is a straightforward and common form of inheritance
'''
print("Single Inheritance--")
class Animal:
    def speak(self):
        print("Animal speaks")

class Dog(Animal):
    def bark(self):
        print("Dog barks")

my_dog = Dog()
my_dog.speak()  
my_dog.bark()  


'''
Multiple Inheritance:
Multiple inheritance occurs when a class inherits from more than one base class. In Python, a subclass can inherit attributes and methods from 
multiple classes. This can lead to complex class hierarchies.
'''
print("\nMultiple Inheritance -- ")
class Flyable:
    def fly(self):
        print("Can fly")

class Swimmable:
    def swim(self):
        print("Can swim")

class Amphibian(Flyable, Swimmable):
    def jump(self):
        print("Can jump")

frog = Amphibian()

frog.fly()   
frog.swim()  
frog.jump()
# Out:
# Single Inheritance--
# Animal speaks
# Dog barks
#
# Multiple Inheritance --
# Can fly
# Can swim
# Can jump

# %%
# 3. Create a Python class called `Vehicle` with attributes `color` and `speed`. Then, create a child class called 
# `Car` that inherits from `Vehicle` and adds a `brand` attribute. Provide an example of creating a `Car` object.

class Vehicle:
    def __init__(self, color, speed):
        self.color = color
        self.speed = speed

class Car(Vehicle):
    def __init__(self, color, speed, brand):
        # Call the constructor of the base class (Vehicle) to initialize color and speed
        super().__init__(color, speed)
        self.brand = brand

my_car = Car(color="Blue", speed=60, brand="Toyota")

print("Color:", my_car.color)
print("Speed:", my_car.speed)
print("Brand:", my_car.brand)
# Out:
# Color: Blue
# Speed: 60
# Brand: Toyota

# %%
# 4. Explain the concept of method overriding in inheritance. Provide a practical example.
'''
Method overriding is an ability of any object-oriented programming language that allows a subclass or child class to provide a specific implementation 
of a method that is already provided by one of its super-classes or parent classes. When a method in a subclass has the same name, same parameters or 
signature and same return type(or sub-type) as a method in its super-class, then the method in the subclass is said to override the method in the 
super-class.
'''
class Animal:
    def speak(self):
        print("Animal speaks")

class Dog(Animal):
    # Overriding the speak method in the subclass
    def speak(self):
        print("Dog barks")

class Cat(Animal):
    # Overriding the speak method in the subclass
    def speak(self):
        print("Cat meows")

# Creating instances of Dog and Cat
my_dog = Dog()
my_cat = Cat()

# Calling the speak method on instances
my_dog.speak()  
my_cat.speak()
# Out:
# Dog barks
# Cat meows

# %%
# 5. How can you access the methods and attributes of a parent class from a child class in Python? Give an example.
'''
In Python, you can access the methods and attributes of a parent (or base) class from a child (or derived) class using the super() function. 
The super() function returns a temporary object of the superclass, which allows you to call its methods and access its attributes.
'''
class Animal:
    def __init__(self, species):
        self.species = species

    def make_sound(self):
        print("Generic animal sound")

class Dog(Animal):
    def __init__(self, species, breed):
        # Calling the constructor of the parent class (Animal) using super()
        super().__init__(species)
        self.breed = breed

    def make_sound(self):
        # Calling the overridden method of the parent class (Animal) using super()
        super().make_sound()
        print("Dog barks")

    def display_info(self):
        print(f"This is a {self.species} of breed {self.breed}")


my_dog = Dog(species="Canine", breed="Golden Retriever")

my_dog.make_sound()    
print("Species:", my_dog.species)
my_dog.display_info()
# Out:
# Generic animal sound
# Dog barks
# Species: Canine
# This is a Canine of breed Golden Retriever

# %%
# 6. Discuss the use of the `super()` function in Python inheritance. When and why is it used? Provide an example.
'''
The super() function in Python is used in the context of inheritance to call methods or access attributes of a parent (or superclass) within a 
subclass. It is particularly useful when you want to extend or override methods from the parent class while preserving the functionality of the 
parent class.

The primary purpose of super() is to invoke the methods of the superclass, allowing you to reuse code and maintain a clean and consistent structure
in your object-oriented programs.
'''
class Parent:
    def __init__(self, x):
        self.x = x

class Child(Parent):
    def __init__(self, x, y):
        super().__init__(x)
        self.y = y

    def combined_attribute(self):
        return self.x + self.y

obj = Child(x=10, y=20)
result = obj.combined_attribute()
print(result)
# Out:
# 30

# %%
# 7. Create a Python class called `Animal` with a method `speak()`. Then, create child classes `Dog` and `Cat`
#  that inherit from `Animal` and override the `speak()` method. Provide an example of using these classes.

class Animal:
    def speak(self):
        print("Animal speaks")

class Dog(Animal):
    # Overriding the speak method in the subclass
    def speak(self):
        print("Dog barks")

class Cat(Animal):
    # Overriding the speak method in the subclass
    def speak(self):
        print("Cat meows")

# Creating instances of Dog and Cat
my_dog = Dog()
my_cat = Cat()

# Calling the speak method on instances
my_dog.speak()  
my_cat.speak()
# Out:
# Dog barks
# Cat meows

# %%
#  8. Explain the role of the `isinstance()` function in Python and how it relates to inheritance.
'''

The isinstance() function in Python is used to check if an object is an instance of a specified class or a tuple of classes. It returns True if the 
object is an instance of any of the specified classes, and False otherwise. The function is particularly useful when working with inheritance and
polymorphism, allowing you to determine the type of an object dynamically.
'''
class Animal:
    pass

class Dog(Animal):
    pass

my_dog = Dog()

print(isinstance(my_dog, Dog))    
print(isinstance(my_dog, Animal))
# Out:
# True
# True

# %%
# 9. What is the purpose of the `issubclass()` function in Python? Provide an example.
'''
The issubclass() function in Python is used to check if a class is a subclass of another class. It returns True if the first class is a subclass 
of the second class, and False otherwise. This function is useful for checking class relationships and hierarchy.
'''
class Animal:
    pass

class Mammal(Animal):
    pass

class Dog(Mammal):
    pass

# Checking subclass relationships
print(issubclass(Mammal, Animal))  # Output: True (Mammal is a subclass of Animal)
print(issubclass(Dog, Mammal))      # Output: True (Dog is a subclass of Mammal)
print(issubclass(Dog, Animal))      # Output: True (Dog is a subclass of Animal)

# Checking against multiple classes
print(issubclass(Dog, (Mammal, Animal)))  # Output: True (Dog is a subclass of Mammal and Animal)
print(issubclass(Mammal, (Dog, Animal)))  # Output: False (Mammal is not a subclass of Dog or Animal)
# Out:
# True
# True
# True
# True
# True

# %%
#  10. Discuss the concept of constructor inheritance in Python. How are constructors inherited in child classes?
'''
In Python, constructor inheritance refers to the process by which a child class inherits the constructor (also known as the initializer) of its parent
class. The constructor is a special method in Python classes that is responsible for initializing the object's attributes when an instance of the 
class is created.
'''

class Parent:
    def __init__(self, parent_attribute):
        self.parent_attribute = parent_attribute
        print("Parent constructor called")

class Child(Parent):
    def __init__(self, parent_attribute, child_attribute):
        # Calling the constructor of the parent class using super()
        super().__init__(parent_attribute)
        self.child_attribute = child_attribute
        print("Child constructor called")

obj = Child("Parent Value", "Child Value")
# Out:
# Parent constructor called
# Child constructor called

# %%
# 11. Create a Python class called `Shape` with a method `area()` that calculates the area of a shape. Then, create child classes
# `Circle` and `Rectangle` that inherit from `Shape` and implement the `area()` method accordingly. Provide an example.

import math

class Shape:
    def area(self):
        # The base class has a generic area method, which should be overridden by subclasses.
        raise NotImplementedError("Subclasses must implement the area method.")

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius**2

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

c1 = Circle(radius=5)
r1 = Rectangle(width=4, height=6)

# Calculating and printing the areas
print(f"Circle Area: {c1.area()}")
print(f"Rectangle Area: {r1.area()}")
# Out:
# Circle Area: 78.53981633974483
# Rectangle Area: 24

# %%
# 12. Explain the use of abstract base classes (ABCs) in Python and how they relate to inheritance. Provide an example using the `abc` module.

'''
Abstract Base Classes (ABCs) in Python provide a way to define abstract classes and abstract methods. An abstract class is a class that cannot be
instantiated and is meant to be subclassed by other classes. Abstract methods are methods declared in the abstract class but do not contain an
implementation. Subclasses are required to provide concrete implementations for these abstract methods.
'''
from abc import ABC, abstractmethod

# Define an abstract base class called Vehicle
class Vehicle(ABC):
    @abstractmethod
    def start(self):
        pass

    @abstractmethod
    def stop(self):
        pass

# Create a concrete subclass Car that inherits from Vehicle
class Car(Vehicle):
    def start(self):
        return "Car started"

    def stop(self):
        return "Car stopped"

# Create another concrete subclass Bicycle that inherits from Vehicle
class Bicycle(Vehicle):
    def start(self):
        return "Bicycle started"

    def stop(self):
        return "Bicycle stopped"


car1 = Car()
bicycle1 = Bicycle()

# Call the start and stop methods
print(car1.start())  
print(car1.stop()) 

print(bicycle1.start())  
print(bicycle1.stop())
# Out:
# Car started
# Car stopped
# Bicycle started
# Bicycle stopped

# %%
# 13. How can you prevent a child class from modifying certain attributes or methods inherited from a parent class in Python?
'''
You can make attributes private in the parent class by prefixing them with a double underscore (__). This makes them harder to access or modify from
outside the class. However, it doesn't make them completely immutable.
'''
class Parent:
    def __init__(self):
        self.__immutable_attribute = "Cannot be modified"

class Child(Parent):
    def modify_attribute(self, new_value):
        # This will result in an AttributeError
        self.__immutable_attribute = new_value
        #print( self.__immutable_attribute)
child1 = Child()
# This will raise an AttributeError
child1.modify_attribute("New Value")

# %%
# 14. Create a Python class called `Employee` with attributes `name` and `salary`. Then, create a child class `Manager` 
# that inherits from `Employee` and adds an attribute `department`. Provide an example.

class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def display_info(self):
        return f"Name: {self.name}, Salary: ${self.salary}"

class Manager(Employee):
    def __init__(self, name, salary, department):
        # Call the constructor of the parent class using super()
        super().__init__(name, salary)
        self.department = department

    # Override the display_info method to include department information
    def display_info(self):
        base_info = super().display_info()
        return f"{base_info}, Department: {self.department}"


employee1 = Employee(name="John Doe", salary=50000)
manager1 = Manager(name="Alice Smith", salary=80000, department="Sales")

print(employee1.display_info())
print(manager1.display_info())
# Out:
# Name: John Doe, Salary: $50000
# Name: Alice Smith, Salary: $80000, Department: Sales

# %%
# 15. Discuss the concept of method overloading in Python inheritance. How does it differ from method overriding?
'''
Method overloading refers to the ability to define multiple methods in the same class with the same name but with a different number or type of 
parameters. Unlike some other programming languages, Python does not support true method overloading by default. However, you can achieve a similar
effect using default parameter values and variable-length argument lists.
'''
print("Method OverLoading")
class OverloadExample:
    def display(self, x=None, y=None):
        if x is not None and y is not None:
            print(f"Two arguments: {x}, {y}")
        elif x is not None:
            print(f"One argument: {x}")
        else:
            print("No arguments")

obj = OverloadExample()
obj.display()               
obj.display(1)              
obj.display(2, 3)
'''
Method overriding occurs when a subclass provides a specific implementation for a method that is already defined in its superclass. The overridden 
method in the subclass has the same name and signature as the method in the superclass. This allows the subclass to provide a specialized version of
the method while still maintaining the same interface.
'''
print("\nMethod Overriding")
class Parent:
    def display_info(self):
        print("Parent class method")

class Child(Parent):
    def display_info(self):
        print("Child class method")


parent_obj = Parent()
child_obj = Child()

parent_obj.display_info()   
child_obj.display_info()
# Out:
# Method OverLoading
# No arguments
# One argument: 1
# Two arguments: 2, 3
#
# Method Overriding
# Parent class method
# Child class method

# %%
#  16. Explain the purpose of the `__init__()` method in Python inheritance and how it is utilized in child classes.
'''
In Python, the __init__() method is a special method, also known as a constructor, that is automatically called when an object is created from a class.
Its purpose is to initialize the object's attributes. In the parent class, the __init__() method is responsible for initializing the attributes that 
are common to all instances of the class. It sets up the initial state of the object.
When a child class inherits from a parent class, it can have its own __init__() method in addition to the one in the parent class. The child 
class's __init__() method can call the parent class's __init__() method using super() to initialize the attributes inherited from the parent class, 
and it can also define additional attributes specific to the child class.
'''
class Parent:
    def __init__(self, name, age):
        self.name = name
        self.age = age


parent = Parent(name="Rohit", age=30)

class Child(Parent):
    def __init__(self, name, age, grade):
        # Call the __init__ method of the parent class
        super().__init__(name, age)
        
        # Initialize the additional attribute specific to the child class
        self.grade = grade

child = Child(name="Debu", age=12, grade="A")

print(parent.name)
print(child.name)
# Out:
# Rohit
# Debu

# %%
# 17. Create a Python class called `Bird` with a method `fly()`. Then, create child classes `Eagle` and `Sparrow`
# that inherit from `Bird` and implement the `fly()` method differently. Provide an example of using these classes.

class Bird:
    def fly(self):
        return "Bird is flying"

class Eagle(Bird):
    def fly(self):
        return "Eagle soars high in the sky"

class Sparrow(Bird):
    def fly(self):
        return "Sparrow flutters around the garden"


bird1 = Bird()
eagle1 = Eagle()
sparrow1 = Sparrow()

print(bird1.fly())       
print(eagle1.fly())      
print(sparrow1.fly())
# Out:
# Bird is flying
# Eagle soars high in the sky
# Sparrow flutters around the garden

# %%
# 18. What is the "diamond problem" in multiple inheritance, and how does Python address it?
'''
The "diamond problem" is a term used in the context of multiple inheritance in object-oriented programming. It occurs when a class inherits from two
classes that have a common ancestor. If both parent classes provide an implementation for a method, and the child class does not override that method,
it becomes ambiguous which method should be called.
'''
class A:
    def method(self):
        print("Method in class A")

class B(A):
    def method(self):
        print("Method in class B")

class C(A):
    def method(self):
        print("Method in class C")

class D(B, C):
    pass


obj_d = D()
obj_d.method()


'''
How Python Addresses the Diamond Problem:
Python addresses the diamond problem by using a method resolution order (MRO) to determine the order in which base classes are considered when looking
for a method or attribute. The C3 linearization algorithm is used to calculate the MRO.

In Python, the MRO is accessible via the __mro__ attribute or the mro() method. When a method is called on an instance, Python searches for that method
in the MRO from left to right.
'''
class A:
    def method(self):
        print("Method in class A")

class B(A):
    def method(self):
        print("Method in class B")

class C(A):
    def method(self):
        print("Method in class C")

class D(B, C):
    pass


obj_d = D()
obj_d.method()

# Print the method resolution order (MRO)
print(D.__mro__)
# Out:
# Method in class B
# Method in class B
# (<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>)

# %%
# 19. Discuss the concept of "is-a" and "has-a" relationships in inheritance, and provide examples of each.
'''
Inheritance in object-oriented programming often involves establishing relationships between classes. Two common types of relationships are "is-a" 
and "has-a."

"is-a" Relationship:
The "is-a" relationship represents a type of relationship where one class is a subclass of another. It implies that an object of the subclass type can
be used wherever an object of the superclass type is expected. This relationship is often used to model specialization and generalization.
'''
class Shape:
    def draw(self):
        pass

class Circle(Shape):
    def draw(self):
        print("Drawing a circle")

class Square(Shape):
    def draw(self):
        print("Drawing a square")
'''
In this example:

Circle and Square are subclasses of Shape.
An object of type Circle or Square can be treated as an object of type Shape.
This relationship reflects an "is-a" relationship, as a circle "is-a" shape and a square "is-a" shape.
'''

'''
"has-a" Relationship:
The "has-a" relationship represents a type of relationship where one class contains an instance of another class. It implies that an object of one
class contains, or is composed of, objects of another class. This relationship is often used to model composition or aggregation.
'''
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author

class Library:
    def __init__(self):
        self.books = []

    def add_book(self, book):
        self.books.append(book)
        
'''
In this example:

Library has a list of Book objects (self.books).
The Library class contains an instance of the Book class, establishing a "has-a" relationship.
This relationship reflects that a library "has-a" collection of books.

'''
# Out:
# '\nIn this example:\n\nLibrary has a list of Book objects (self.books).\nThe Library class contains an instance of the Book class, establishing a "has-a" relationship.\nThis relationship reflects that a library "has-a" collection of books.\n\n'

# %%
# 20. Create a Python class hierarchy for a university system. Start with a base class `Person` and create childclasses `Student` and `Professor`, 
# each with their own attributes and methods. Provide an example of using these classes in a university context.

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display_info(self):
        return f"Name: {self.name}, Age: {self.age}"

class Student(Person):
    def __init__(self, name, age, student_id):
        super().__init__(name, age)
        self.student_id = student_id

    def display_info(self):
        base_info = super().display_info()
        return f"{base_info}, Student ID: {self.student_id}"

    def study(self):
        return f"{self.name} is studying"

class Professor(Person):
    def __init__(self, name, age, employee_id):
        super().__init__(name, age)
        self.employee_id = employee_id

    def display_info(self):
        base_info = super().display_info()
        return f"{base_info}, Employee ID: {self.employee_id}"

    def teach(self):
        return f"{self.name} is teaching"


student1 = Student(name="Animesh", age=22, student_id="S12345")
professor1= Professor(name="Dr. Avijit", age=45, employee_id="P98765")


print(student1.display_info())
print(student1.study())

print(professor1.display_info())
print(professor1.teach())
# Out:
# Name: Animesh, Age: 22, Student ID: S12345
# Animesh is studying
# Name: Dr. Avijit, Age: 45, Employee ID: P98765
# Dr. Avijit is teaching

# %% [markdown]
# -------------------------------------------------  Encapsulation:  --------------------------------------

# %%
# 1. Explain the concept of encapsulation in Python. What is its role in object-oriented programming?

'''

Encapsulation is one of the fundamental principles of object-oriented programming (OOP) and refers to the bundling of data (attributes) and the
methods (functions) that operate on the data into a single unit, known as a class. It involves restricting direct access to some of an object's 
components and can prevent unintended interference or misuse. Encapsulation helps in organizing the code, hiding the implementation details, and
promoting a clean and modular design.

'''

# %%
# 2. Describe the key principles of encapsulation, including access control and data hiding.
'''
Encapsulation in object-oriented programming involves bundling the data (attributes) and the methods (functions) that operate on the data into a
single unit, known as a class. The key principles of encapsulation include access control and data hiding:

1. Access Control:
Public Access (Default): Attributes and methods are accessible from outside the class. This is the default behavior if no access modifier is specified.
'''
class MyClass:
    def __init__(self):
        self.public_attribute = 42  # Public attribute
    
    def public_method(self):
        return "This is a public method"
'''

Protected Access (_ prefix): 
Attributes and methods with a single leading underscore are considered protected. They are intended for internal use but can still be accessed from
outside the class.
'''
class MyClass:
    def __init__(self):
        self._protected_attribute = 42  # Protected attribute
    
    def _protected_method(self):
        return "This is a protected method"
    
    
    
'''
Private Access (__ prefix): 
Attributes and methods with a double leading underscore are considered private. They are not directly accessible from outside the class.
'''
class MyClass:
    def __init__(self):
        self.__private_attribute = 42  # Private attribute
    
    def __private_method(self):
        return "This is a private method"

    
    
'''

2. Data Hiding:

Hide Internal State: 
Encapsulation hides the internal state (attributes) of an object, making it accessible only through the defined methods.
'''
class Car:
    def __init__(self, make, model):
        self._make = make   # Encapsulation: _make is a protected attribute
        self._model = model  # Encapsulation: _model is a protected attribute
        self._mileage = 0    # Encapsulation: _mileage is a protected attribute

        
'''
Getter and Setter Methods: 
Controlled access to attributes is provided through getter and setter methods. This allows for additional logic or 
validation when getting or setting attribute values.
'''
class Car:
    # ...

    def get_make(self):
        return self._make

    def set_make(self, make):
        # Additional logic or validation can be added here
        self._make = make

# %%
# 3. How can you achieve encapsulation in Python classes? Provide an example.
'''
Encapsulation is achieved by declaring a class’s data members and methods as either private or protected. But in Python, we do not have keywords like
public, private, and protected, as in the case of Java. Instead, we achieve this by using single and double underscores.
'''
#Public Access (Default): Attributes and methods are accessible from outside the class. This is the default behavior if no access modifier is specified.

class MyClass:
    def __init__(self):
        self.public_attribute = 42  # Public attribute
    
    def public_method(self):
        return "This is a public method"
'''

Protected Access (_ prefix): 
Attributes and methods with a single leading underscore are considered protected. They are intended for internal use but can still be accessed from
outside the class.
'''
class MyClass:
    def __init__(self):
        self._protected_attribute = 42  # Protected attribute
    
    def _protected_method(self):
        return "This is a protected method"
    
    
    
'''
Private Access (__ prefix): 
Attributes and methods with a double leading underscore are considered private. They are not directly accessible from outside the class.
'''
class MyClass:
    def __init__(self):
        self.__private_attribute = 42  # Private attribute
    
    def __private_method(self):
        return "This is a private method"

# %%
# 4. Discuss the difference between public, private, and protected access modifiers in Python.

'''
Public Access Modifier
By default the member variables and methods are public which means they can be accessed from anywhere outside or inside the class. No public keyword 
is required to make the class or methods and properties public.Here is an example of Public access modifier −


Private Access Modifier
Class properties and methods with private access modifier can only be accessed within the class where they are defined and cannot be accessed outside
the class. In Python private properties and methods are declared by adding a prefix with two underscores(‘__’) before their declaration.

Protected Access Modifier
Class properties and methods with protected access modifier can be accessed within the class and from the class that inherits the protected class.
In python, protected members and methods are declared using single underscore(‘_’) as prefix before their names

'''

# %%
# 5. Create a Python class called `Person` with a private attribute `__name`. Provide methods to get and set the name attribute.

class Person:
    def __init__(self, name):
        self.__name = name

    def get_name(self):
        return self.__name

    def set_name(self, new_name):
        self.__name = new_name


person1 = Person("Animesh")

# Get the name using the get_name method
current_name = person1.get_name()
print("Current Name:", current_name)

# Set a new name using the set_name method
person1.set_name("Animesh Samanta")

# Get the updated name
updated_name = person1.get_name()
print("Updated Name:", updated_name)
# Out:
# Current Name: Animesh
# Updated Name: Animesh Samanta

# %%
# 6. Explain the purpose of getter and setter methods in encapsulation. Provide examples.
'''
Getter and setter methods in encapsulation serve the purpose of controlling access to the attributes of a class. Encapsulation is one of the 
fundamental principles of object-oriented programming, aiming to bundle the data (attributes) and the methods (functions) that operate on the data
into a single unit called a class. Getter and setter methods help enforce encapsulation by providing controlled access to the attributes of a class.

Purpose of Getter Methods:
1. Read-Only Access: Getter methods allow you to retrieve the values of private attributes from outside the class without allowing direct access to 
    the attribute itself.
2. Data Validation: You can include additional logic in the getter methods to validate the retrieved data before returning it.

Purpose of Setter Methods:
1. Write Access with Validation: Setter methods allow controlled modification of the private attributes. They enable you to apply validation logic 
   before accepting and assigning a new value to an attribute.
2. Encapsulation Enforcement: By using setter methods, you can ensure that any changes to the internal state of the object go through a controlled 
   interface, preventing unintended or malicious modifications.

'''
class Person:
    def __init__(self, name, age):
        self.__name = name
        self.__age = age

    # Getter methods
    def get_name(self):
        return self.__name

    def get_age(self):
        return self.__age

    # Setter methods
    def set_name(self, new_name):
        # Additional validation can be added here
        self.__name = new_name

    def set_age(self, new_age):
        # Additional validation can be added here
        self.__age = new_age


person1 = Person("Animesh", 20)

# Using getter methods
current_name = person1.get_name()
current_age = person1.get_age()
print("Current Name:", current_name)
print("Current Age:", current_age)

# Using setter methods
person1.set_name("Animesh Samanta")
person1.set_age(22)

# Getting updated values
updated_name = person1.get_name()
updated_age = person1.get_age()
print("Updated Name:", updated_name)
print("Updated Age:", updated_age)
# Out:
# Current Name: Animesh
# Current Age: 20
# Updated Name: Animesh Samanta
# Updated Age: 22

# %%
# 7. What is name mangling in Python, and how does it affect encapsulation?
'''
Name mangling in Python is a mechanism that adds a prefix to the names of attributes in a class to make them less accessible from outside the class.
This is achieved by adding a double underscore (__) as a prefix to the attribute name. The purpose of name mangling is not to make the attribute truly
private or secure, but rather to minimize the chance of accidental name conflicts in large codebases with multiple classes and to discourage external
access.

When name mangling is applied to an attribute, the interpreter changes the name of the attribute to _classname__attribute. Here, classname is the name
of the class to which the attribute belongs. This modification occurs during the compilation phase, and it helps prevent accidental name clashes that 
may occur when different classes have attributes with the same name.
'''

class MyClass:
    def __init__(self):
        self.__private_attribute = 10

    def get_private_attribute(self):
        return self.__private_attribute


obj = MyClass()

# Accessing the private attribute using the name-mangled version
print(obj._MyClass__private_attribute)  

# Using the getter method
print(obj.get_private_attribute())
# Out:
# 10
# 10

# %%
# 8. Create a Python class called `BankAccount` with private attributes for the account balance (`__balance`)and account number (`__account_number`).
# Provide methods for depositing and withdrawing money.

class BankAccount:
    def __init__(self, account_number, initial_balance=0):
        self.__account_number = account_number
        self.__balance = initial_balance

    def deposit(self, amount):
        """Deposit money into the account."""
        if amount > 0:
            self.__balance += amount
            print(f"Deposited ${amount}. New balance: ${self.__balance}")
        else:
            print("Invalid deposit amount. Please deposit an amount greater than zero.")

    def withdraw(self, amount):
        """Withdraw money from the account."""
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew ${amount}. New balance: ${self.__balance}")
        elif amount > self.__balance:
            print("Insufficient funds. Withdrawal amount exceeds the account balance.")
        else:
            print("Invalid withdrawal amount. Please withdraw an amount greater than zero.")

    def get_balance(self):
        """Get the current account balance."""
        return self.__balance

    def get_account_number(self):
        """Get the account number."""
        return self.__account_number


account_number = "123456789"
initial_balance = 1000

account = BankAccount(account_number, initial_balance)

account.deposit(500)
account.withdraw(200)
account.withdraw(900)  

current_balance = account.get_balance()
current_account_number = account.get_account_number()

print("Current Balance:", current_balance)
print("Account Number:", current_account_number)
# Out:
# Deposited $500. New balance: $1500
# Withdrew $200. New balance: $1300
# Withdrew $900. New balance: $400
# Current Balance: 400
# Account Number: 123456789

# %%
# 9. Discuss the advantages of encapsulation in terms of code maintainability and security.

Access Control:
Encapsulation provides a way to control access to sensitive or critical data by making attributes private. This prevents external code from directly
manipulating or reading sensitive information.

Prevention of Unintended Changes:
With encapsulation, the internal state of an object is protected from unintended modifications. Changes to the state can only occur through controlled
methods, reducing the risk of unintended side effects.

Encapsulation as a Barrier:
While not a foolproof security measure, encapsulation acts as a barrier, making it more challenging for external code to interfere with the internal
workings of a class. It adds a layer of protection against accidental misuse or intentional tampering.

# %%
# 10. How can you access private attributes in Python? Provide an example demonstrating the use of namemangling.

class MyClass:
    def __init__(self):
        self.__private_attribute = 10

    def get_private_attribute(self):
        return self.__private_attribute


obj = MyClass()

# Accessing the private attribute using the name-mangled version
print(obj._MyClass__private_attribute)  

# Using the getter method
print(obj.get_private_attribute())
# Out:
# 10
# 10

# %%
# 11. Create a Python class hierarchy for a school system, including classes for students, teachers, and courses,
# and implement encapsulation principles to protect sensitive information.

class Person:
    def __init__(self, name, age):
        self.__name = name
        self.__age = age

    def get_name(self):
        return self.__name

    def set_name(self, new_name):
        self.__name = new_name

    def get_age(self):
        return self.__age

    def set_age(self, new_age):
        self.__age = new_age


class Student(Person):
    def __init__(self, name, age, student_id):
        super().__init__(name, age)
        self.__student_id = student_id
        self.__courses = []

    def get_student_id(self):
        return self.__student_id

    def enroll_in_course(self, course):
        self.__courses.append(course)
        print(f"{self.get_name()} enrolled in {course.get_course_name()}")

    def get_courses(self):
        return self.__courses


class Teacher(Person):
    def __init__(self, name, age, employee_id):
        super().__init__(name, age)
        self.__employee_id = employee_id
        self.__courses_taught = []

    def get_employee_id(self):
        return self.__employee_id

    def assign_course(self, course):
        self.__courses_taught.append(course)
        print(f"{self.get_name()} assigned to teach {course.get_course_name()}")

    def get_courses_taught(self):
        return self.__courses_taught


class Course:
    def __init__(self, course_name, course_code):
        self.__course_name = course_name
        self.__course_code = course_code

    def get_course_name(self):
        return self.__course_name

    def set_course_name(self, new_name):
        self.__course_name = new_name

    def get_course_code(self):
        return self.__course_code

    def set_course_code(self, new_code):
        self.__course_code = new_code


student = Student("Animesh Samanta", 22, "S12345")
teacher = Teacher("Mr. Avijit", 40, "T1345")
math_course = Course("Mathematics", "MATH101")

# Accessing and modifying information using getter and setter methods
student.set_name("Akash Chowdhury")
teacher.set_age(21)
math_course.set_course_code("MATH102")

# Performing actions using class methods
student.enroll_in_course(math_course)
teacher.assign_course(math_course)

# Displaying information
print(f"Student Name: {student.get_name()}, ID: {student.get_student_id()}")
print(f"Teacher Name: {teacher.get_name()}, Employee ID: {teacher.get_employee_id()}")
print(f"Course Name: {math_course.get_course_name()}, Code: {math_course.get_course_code()}")
# Out:
# Akash Chowdhury enrolled in Mathematics
# Mr. Avijit assigned to teach Mathematics
# Student Name: Akash Chowdhury, ID: S12345
# Teacher Name: Mr. Avijit, Employee ID: T1345
# Course Name: Mathematics, Code: MATH102

# %%
# 12. Explain the concept of property decorators in Python and how they relate to encapsulation.

'''

In Python, property decorators are a way to implement getter, setter, and deleter methods in a class, allowing you to control the access and
modification of class attributes. Property decorators make it possible to define methods that can be accessed and modified like attributes, providing
a clean and intuitive interface while still allowing for encapsulation.
'''
class MyClass:
    def __init__(self):
        self._x = None

    @property
    def x(self):
        return self._x

    @x.setter
    def x(self, value):
        # Additional validation or logic can be added here
        self._x = value

    @x.deleter
    def x(self):
        print("Deleting x")
        del self._x

        # Example usage of the MyClass with property decorators
obj = MyClass()

# Accessing the property (getter)
print(obj.x)  

# Setting the property (setter)
obj.x = 10

# Deleting the property (deleter)
del obj.x
# Out:
# None
# Deleting x

# %%
# 13. What is data hiding, and why is it important in encapsulation? Provide examples.
'''
Data hiding is a concept in object-oriented programming that refers to the practice of restricting access to certain details of an object and 
preventing the direct exposure of its internal state. In other words, it involves hiding the implementation details of a class and exposing only 
what is necessary for the outside world to interact with the object.
'''
class BankAccount:
    def __init__(self, account_number, balance):
        self._account_number = account_number  
        self.__balance = balance  

    def get_balance(self):
        return self.__balance

    def set_balance(self, new_balance):
        if new_balance >= 0:
            self.__balance = new_balance
        else:
            print("Invalid balance. Balance cannot be negative.")

account = BankAccount("123456789", 1000)

print("Account Number:", account._account_number)

current_balance = account.get_balance()
print("Current Balance:", current_balance)

account.set_balance(2000)
updated_balance = account.get_balance()
print("Updated Balance:", updated_balance)
# Out:
# Account Number: 123456789
# Current Balance: 1000
# Updated Balance: 2000

# %%
# 14. Create a Python class called `Employee` with private attributes for salary (`__salary`) and employee ID (`__employee_id`).
#  Provide a method to calculate yearly bonuses. 

class Employee:
    def __init__(self, employee_id, salary):
        self.__employee_id = employee_id
        self.__salary = salary

    def calculate_yearly_bonus(self, bonus_percentage):
        """Calculate and return the yearly bonus based on the bonus_percentage."""
        if 0 <= bonus_percentage <= 100:
            bonus_amount = (bonus_percentage / 100) * self.__salary
            return bonus_amount
        else:
            print("Invalid bonus percentage. Please provide a percentage between 0 and 100.")
            return 0

    def get_employee_id(self):
        return self.__employee_id

    def get_salary(self):
        return self.__salary


employee1 = Employee("E12345", 50000)

# Accessing private attributes using getter methods (optional)
employee_id = employee1.get_employee_id()
salary = employee1.get_salary()

print(f"Employee ID: {employee_id}")
print(f"Salary: ${salary}")

bonus_percentage = 15 
yearly_bonus = employee1.calculate_yearly_bonus(bonus_percentage)
print(f"Yearly Bonus: ${yearly_bonus}")
# Out:
# Employee ID: E12345
# Salary: $50000
# Yearly Bonus: $7500.0

# %%
# 15. Discuss the use of accessors and mutators in encapsulation. How do they help maintain control over attribute access?

# %%
# 16. What are the potential drawbacks or disadvantages of using encapsulation in Python?

Complexity and Verbosity:
Implementing encapsulation often requires creating getter and setter methods for each attribute, leading to more verbose code.
The increased number of methods can make the class interface more complex, especially for simple classes.

Performance Overhead:
Using accessor and mutator methods may introduce a slight performance overhead compared to direct attribute access.
In performance-critical applications, the additional method calls may impact execution speed.

Limited Flexibility:
Encapsulation can make it challenging to work with certain Python features that rely on direct attribute access,
such as certain serialization or data manipulation libraries.
Some external tools or frameworks may not integrate seamlessly with classes that heavily use encapsulation.

# %%
# 17. Create a Python class for a library system that encapsulates book information, including titles, authors, and availability status.

class Book:
    def __init__(self, title, author):
        self.__title = title
        self.__author = author
        self.__available = True

    def get_title(self):
        return self.__title

    def get_author(self):
        return self.__author

    def is_available(self):
        return self.__available

    def borrow_book(self):
        if self.__available:
            self.__available = False
            print(f"Book '{self.__title}' by {self.__author} has been borrowed.")
        else:
            print(f"Book '{self.__title}' is currently not available.")

    def return_book(self):
        if not self.__available:
            self.__available = True
            print(f"Book '{self.__title}' has been returned.")
        else:
            print(f"Book '{self.__title}' is already available.")


book1 = Book("Abol Tabol", "Sukumar Roy")
book2 = Book("Prof. Shanku", "Satyajit Roy")

# Accessing book information using getter methods
print("Book 1 Title:", book1.get_title())
print("Book 1 Author:", book1.get_author())

# Borrowing and returning books
book1.borrow_book()
book2.borrow_book()
book1.return_book()

# Checking availability
print("Is Book 1 available?", book1.is_available())
print("Is Book 2 available?", book2.is_available())
# Out:
# Book 1 Title: Abol Tabol
# Book 1 Author: Sukumar Roy
# Book 'Abol Tabol' by Sukumar Roy has been borrowed.
# Book 'Prof. Shanku' by Satyajit Roy has been borrowed.
# Book 'Abol Tabol' has been returned.
# Is Book 1 available? True
# Is Book 2 available? False

# %%
# 18. Explain how encapsulation enhances code reusability and modularity in Python programs.

Encapsulation enhances code reusability and modularity in Python programs by promoting a clear separation between the implementation details
of a class and the code that interacts with that class. It achieves this through the use of private attributes, methods, and controlled 
access interfaces. Here's how encapsulation contributes to code reusability and modularity:

Modularity:
Encapsulation encourages the grouping of related attributes and methods within a class, creating a modular unit of code.
Each class becomes a self-contained module with its own internal state and behavior.
Changes to the internal implementation of a class do not affect the external code that interacts with the class, promoting modular design.

Information Hiding:
Encapsulation hides the internal details of a class, exposing only a well-defined interface to the outside world.
External code interacts with objects through public methods, abstracting away the complexities of the internal implementation.
This information hiding allows developers to focus on using the provided interface without worrying about the internal details.

Code Reusability:
Encapsulated classes can be reused in different parts of a program or in different projects without modification.
A well-designed class with a clear and controlled interface is more likely to be reused, leading to code reusability.
Reusing encapsulated classes avoids the need to duplicate code, reducing redundancy and promoting a more maintainable codebase.

Encapsulation of Complexity:
Complex behaviors and interactions can be encapsulated within classes, simplifying the overall structure of the program.
External code interacts with the class through high-level methods, abstracting away the internal complexities.
This encapsulation of complexity makes the program more modular, as developers can understand and use classes without delving into their
intricate details.

# %%
# 19. Describe the concept of information hiding in encapsulation. Why is it essential in software development?

Information hiding is a fundamental concept in encapsulation that involves concealing the internal details of an object and exposing only
what is necessary for the object's interaction with the outside world. In other words, it's about hiding the implementation details of a 
class while providing a well-defined interface through which external code can interact with the object.

This concept is essential in software development for several reasons:

Abstraction:
Information hiding allows developers to create abstract representations of objects, focusing on what the object does rather than how it 
achieves its functionality.
Abstraction simplifies the complexity of an object, making it more manageable for developers who interact with the object.

Reduced Complexity:
By hiding the internal details, information hiding reduces the complexity seen by external code.
External code interacts with objects through a limited set of methods, properties, or interfaces, shielding developers from unnecessary 
intricacies.

Modularity:
Information hiding promotes modularity by encapsulating related attributes and methods within a class.
Each class becomes a modular unit, and changes to the internal implementation of a class do not affect other modules, contributing to a
more maintainable and modular codebase.

Enhanced Security:
Hiding the internal details of an object adds a layer of security by preventing external code from accessing or modifying the object's 
state directly.
Access to the internal details is controlled through well-defined interfaces, reducing the risk of unintended interference or misuse.

# %%
# 20. Create a Python class called `Customer` with private attributes for customer details like name, address,
# and contact information. Implement encapsulation to ensure data integrity and security.

class Customer:
    def __init__(self, customer_id, name, address, contact_info):
        self.__customer_id = customer_id
        self.__name = name
        self.__address = address
        self.__contact_info = contact_info

    # Getter methods for private attributes
    def get_customer_id(self):
        return self.__customer_id

    def get_name(self):
        return self.__name

    def get_address(self):
        return self.__address

    def get_contact_info(self):
        return self.__contact_info

    # Setter methods for private attributes (optional)
    def set_name(self, new_name):
        self.__name = new_name

    def set_address(self, new_address):
        self.__address = new_address

    def set_contact_info(self, new_contact_info):
        self.__contact_info = new_contact_info

customer = Customer(customer_id="C12345", name="Animesh Samanta", address="Banipur, North 24 Parganas", contact_info="ani2345@email.com")

# Accessing customer information using getter methods
print("Customer ID:", customer.get_customer_id())
print("Name:", customer.get_name())
print("Address:", customer.get_address())
print("Contact Info:", customer.get_contact_info())


# Modifying customer information using setter methods (optional)
customer.set_name("Akash Chowdhury")
customer.set_address("Nadia, West Bengal")
customer.set_contact_info("akash1234@email.com")

# Displaying updated customer information
print("Updated Name:", customer.get_name())
print("Updated Address:", customer.get_address())
print("Updated Contact Info:", customer.get_contact_info())
# Out:
# Customer ID: C12345
# Name: Animesh Samanta
# Address: Banipur, North 24 Parganas
# Contact Info: ani2345@email.com
# Updated Name: Akash Chowdhury
# Updated Address: Nadia, West Bengal
# Updated Contact Info: akash1234@email.com

# %% [markdown]
# ---------------------------------------------------------------  Polymorphism:  ------------------------------------------------

# %%
# 1. What is polymorphism in Python? Explain how it is related to object-oriented programming.
'''
The word polymorphism means having many forms. In programming, polymorphism means the same function name (but different signatures) being
used for different types. The key difference is the data types and number of arguments used in function.

There are two main types of polymorphism in Python:

1. Compile-Time Polymorphism (Static Binding):
Also known as method overloading or function overloading.
It involves defining multiple methods in a class with the same name but different parameter types or a different number of parameters.
The appropriate method is chosen at compile time based on the method signature.

Example:
'''
def add(x, y, z = 0): 
    return x + y+z
 
print(add(2, 3))
print(add(2, 3, 4))

'''
2. Run-Time Polymorphism (Dynamic Binding):
Also known as method overriding or function overriding.
It involves defining a method in the subclass that is already defined in the parent class.
The appropriate method is chosen at runtime based on the actual type of the object.

Example:
'''
class Animal:
    def make_sound(self):
        pass

class Dog(Animal):
    def make_sound(self):
        return "Woof!"

class Cat(Animal):
    def make_sound(self):
        return "Meow!"

def animal_sound(animal):
    return animal.make_sound()

dog = Dog()
cat = Cat()

print(animal_sound(dog)) 
print(animal_sound(cat))
# Out:
# 5
# 9
# Woof!
# Meow!

# %%
# 2. Describe the difference between compile-time polymorphism and runtime polymorphism in Python.
'''
Compile-time polymorphism:
    	Compile time polymorphism means binding is occuring at compile time
        It can be achieved through static binding
        Inheritance is not involved
        Method overloading is  an example of compile time polymorphism

Runtime polymorphism :
    Run time polymorphism where at run time we came to know which method is going to invoke
    It can be achieved through dynamic binding
    Inheritance is involved
    Method overriding is an example of runtime polymorphism
'''

# %%
# 3. Create a Python class hierarchy for shapes (e.g., circle, square, triangle) and demonstrate polymorphism through a common method, such as `calculate_area()`.

import math

class Shape:
    def calculate_area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return math.pi * self.radius**2

class Square(Shape):
    def __init__(self, side_length):
        self.side_length = side_length

    def calculate_area(self):
        return self.side_length**2

class Triangle(Shape):
    def __init__(self, base, height):
        self.base = base
        self.height = height

    def calculate_area(self):
        return 0.5 * self.base * self.height

# Function to demonstrate polymorphism
def print_area(shape):
    print(f"Area: {shape.calculate_area()}")

circle = Circle(radius=5)
square = Square(side_length=4)
triangle = Triangle(base=3, height=6)

print("Circle:")
print_area(circle)

print("\nSquare:")
print_area(square)

print("\nTriangle:")
print_area(triangle)
# Out:
# Circle:
# Area: 78.53981633974483
#
# Square:
# Area: 16
#
# Triangle:
# Area: 9.0

# %%
# 4. Explain the concept of method overriding in polymorphism. Provide an example.

'''
Method overriding is a concept in object-oriented programming (OOP) where a subclass provides a specific implementation for a method that is
already defined in its superclass. The overridden method in the subclass has the same signature (name, return type, and parameters) as the 
method in the superclass. The purpose of method overriding is to provide a more specialized or customized behavior in the subclass while 
maintaining a common interface.
'''
class Animal:
    def make_sound(self):
        return "Generic animal sound"

class Dog(Animal):
    def make_sound(self):
        return "Woof!"

class Cat(Animal):
    def make_sound(self):
        return "Meow!"

class Bird(Animal):
    pass  # Inherits the make_sound method from the Animal class


animal = Animal()
dog = Dog()
cat = Cat()
bird = Bird()

print("Animal Sound:", animal.make_sound())  
print("Dog Sound:", dog.make_sound())        
print("Cat Sound:", cat.make_sound())       
print("Bird Sound:", bird.make_sound())
# Out:
# Animal Sound: Generic animal sound
# Dog Sound: Woof!
# Cat Sound: Meow!
# Bird Sound: Generic animal sound

# %%
# 5. How is polymorphism different from method overloading in Python? Provide examples for both.

Polymorphism is most commonly associated with inheritance. In Python, child classes, like other programming languages, inherit methods and 
attributes from the parent class. Method Overriding is the process of redefining certain methods and attributes to fit the child class.

# %%
# 6. Create a Python class called `Animal` with a method `speak()`. Then, create child classes like `Dog`, `Cat`, and `Bird`,
# each with their own `speak()` method. Demonstrate polymorphism by calling the `speak()` method on objects of different subclasses.

class Animal:
    def speak(self):
        return "Generic animal sound"

class Dog(Animal):
    def speak(self):
        return "Woof!"

class Cat(Animal):
    def speak(self):
        return "Meow!"

class Bird(Animal):
    def speak(self):
        return "Tweet!"

# Function to demonstrate polymorphism
def animal_speak(animal):
    return animal.speak()


dog = Dog()
cat = Cat()
bird = Bird()

print("Dog says:", animal_speak(dog))   
print("Cat says:", animal_speak(cat))   
print("Bird says:", animal_speak(bird))
# Out:
# Dog says: Woof!
# Cat says: Meow!
# Bird says: Tweet!

# %%
# 7. Discuss the use of abstract methods and classes in achieving polymorphism in Python. Provide an example using the `abc` module.

from abc import ABC, abstractmethod

# Abstract class with an abstract method
class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

# Concrete subclasses implementing the abstract method
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius**2

class Square(Shape):
    def __init__(self, side_length):
        self.side_length = side_length

    def calculate_area(self):
        return self.side_length**2

# Function to demonstrate polymorphism
def print_area(shape):
    print(f"Area: {shape.calculate_area()}")


circle = Circle(radius=5)
square = Square(side_length=4)


print("Circle:")
print_area(circle)

print("\nSquare:")
print_area(square)
# Out:
# Circle:
# Area: 78.5
#
# Square:
# Area: 16

# %%
# 8. Create a Python class hierarchy for a vehicle system (e.g., car, bicycle, boat) and implement a polymorphic `start()` 
# method that prints a message specific to each vehicle type.

class Vehicle:
    def start(self):
        raise NotImplementedError("Subclasses must implement the start method")

class Car(Vehicle):
    def start(self):
        return "Car engine started. Vroom!"

class Bicycle(Vehicle):
    def start(self):
        return "Bicycle pedaling started. Let's ride!"

class Boat(Vehicle):
    def start(self):
        return "Boat engine started. Setting sail!"

# Function to demonstrate polymorphism
def start_vehicle(vehicle):
    return vehicle.start()


car = Car()
bicycle = Bicycle()
boat = Boat()

print("Car:")
print(start_vehicle(car))

print("\nBicycle:")
print(start_vehicle(bicycle))

print("\nBoat:")
print(start_vehicle(boat))
# Out:
# Car:
# Car engine started. Vroom!
#
# Bicycle:
# Bicycle pedaling started. Let's ride!
#
# Boat:
# Boat engine started. Setting sail!

# %%
# 9. Explain the significance of the `isinstance()` and `issubclass()` functions in Python polymorphism.
'''
1. isinstance() Function:
The isinstance() function is used to check if an object is an instance of a particular class or a tuple of classes. It is particularly 
useful in determining the type of an object, which is essential in scenarios where polymorphism is employed.
'''
class Animal:
    pass

class Dog(Animal):
    pass

dog_instance = Dog()

# Check if dog_instance is an instance of Dog or Animal
print(isinstance(dog_instance, Dog))    

print(isinstance(dog_instance, Animal)) 

print(isinstance(dog_instance, str))   


'''
2. issubclass() Function:
The issubclass() function checks whether a class is a subclass of another class or a tuple of classes. It is valuable when dealing with
class hierarchies and determining the inheritance relationships between classes.
'''
class Animal:
    pass

class Mammal(Animal):
    pass

# Check if Mammal is a subclass of Animal
print(issubclass(Mammal, Animal))  

print(issubclass(Animal, Mammal)) 

print(issubclass(int, Animal))
# Out:
# True
# True
# False
# True
# False
# False

# %%
# 10. What is the role of the `@abstractmethod` decorator in achieving polymorphism in Python? Provide an example.

'''
The @abstractmethod decorator in Python is part of the abc (abstract base classes) module and is used to declare abstract methods within 
abstract classes. Abstract methods are methods that have no implementation in the abstract class itself but must be implemented by concrete
subclasses. The @abstractmethod decorator enforces that subclasses must provide a concrete implementation for the declared method, ensuring
a common interface across multiple classes and enabling polymorphic behavior.
'''
from abc import ABC, abstractmethod

# Abstract class with an abstract method
class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

# Concrete subclasses implementing the abstract method
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius**2

class Square(Shape):
    def __init__(self, side_length):
        self.side_length = side_length

    def calculate_area(self):
        return self.side_length**2

# Function to demonstrate polymorphism
def print_area(shape):
    print(f"Area: {shape.calculate_area()}")


circle = Circle(radius=5)
square = Square(side_length=4)

print("Circle:")
print_area(circle)

print("\nSquare:")
print_area(square)
# Out:
# Circle:
# Area: 78.5
#
# Square:
# Area: 16

# %%
# 11. Create a Python class called `Shape` with a polymorphic method `area()` that calculates the area of different shapes (e.g., circle, rectangle, triangle).

import math

class Shape:
    def area(self):
        raise NotImplementedError("Subclasses must implement the area method")

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius**2

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

class Triangle(Shape):
    def __init__(self, base, height):
        self.base = base
        self.height = height

    def area(self):
        return 0.5 * self.base * self.height

# Function to demonstrate polymorphism
def print_area(shape):
    print(f"Area: {shape.area()}")


circle = Circle(radius=5)
rectangle = Rectangle(length=4, width=6)
triangle = Triangle(base=3, height=8)

print("Circle:")
print_area(circle)

print("\nRectangle:")
print_area(rectangle)

print("\nTriangle:")
print_area(triangle)
# Out:
# Circle:
# Area: 78.53981633974483
#
# Rectangle:
# Area: 24
#
# Triangle:
# Area: 12.0

# %%
# 12. Discuss the benefits of polymorphism in terms of code reusability and flexibility in Python programs.
'''
Polymorphism in Python brings several benefits to code reusability and flexibility, making programs more adaptable and easier to maintain. 
Here are some key advantages:

Code Reusability:
Polymorphism allows the same interface (method) to be used with different types of objects.
A common set of methods can be defined in a base class or interface, and these methods can be reused by multiple subclasses.
This promotes a modular and reusable design, reducing code duplication.

Flexibility and Extensibility:
Polymorphism allows new classes to be added to the system without modifying existing code.
New subclasses can extend existing classes or implement common interfaces, providing additional functionality without affecting the
existing codebase.
This flexibility facilitates the addition of new features and modifications to the software.

Ease of Maintenance:
Polymorphism simplifies maintenance by promoting a modular and encapsulated design.
Changes to the implementation of a specific class do not affect the code that uses the class through a common interface.
Modifying or extending functionality can be done without impacting the entire codebase.

Reduced Dependencies:
Polymorphism helps reduce dependencies between different parts of the code.
Code that uses polymorphic interfaces relies on abstract behaviors rather than concrete implementations, reducing coupling between 
components.
'''

# %%
# 13. Explain the use of the `super()` function in Python polymorphism. How does it help call methods of parent classes?

'''

The super() function in Python is used to call methods from the parent class within a subclass. It is particularly useful in the context of
polymorphism when you have overridden a method in a subclass and want to invoke the method from the parent class
'''
class Animal:
    def speak(self):
        return "Generic animal sound"

class Dog(Animal):
    def speak(self):
        # Call the speak method of the parent class (Animal)
        return super().speak() + " and Woof!"

dog = Dog()
print(dog.speak())
# Out:
# Generic animal sound and Woof!

# %%
# 14. Create a Python class hierarchy for a banking system with various account types (e.g., savings, checking,credit card) and 
# demonstrate polymorphism by implementing a common `withdraw()` method.

class BankAccount:
    def __init__(self, account_number, balance):
        self.account_number = account_number
        self.balance = balance

    def withdraw(self, amount):
        raise NotImplementedError("Subclasses must implement the withdraw method")

    def display_balance(self):
        return f"Account Number: {self.account_number}, Balance: ${self.balance:.2f}"

class SavingsAccount(BankAccount):
    def __init__(self, account_number, balance, interest_rate):
        super().__init__(account_number, balance)
        self.interest_rate = interest_rate

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            return f"Withdrawal of ${amount:.2f} from savings account successful."
        else:
            return "Insufficient funds."

class CheckingAccount(BankAccount):
    def __init__(self, account_number, balance, overdraft_limit):
        super().__init__(account_number, balance)
        self.overdraft_limit = overdraft_limit

    def withdraw(self, amount):
        if amount <= self.balance + self.overdraft_limit:
            self.balance -= amount
            return f"Withdrawal of ${amount:.2f} from checking account successful."
        else:
            return "Insufficient funds."

class CreditCardAccount(BankAccount):
    def __init__(self, account_number, balance, credit_limit):
        super().__init__(account_number, balance)
        self.credit_limit = credit_limit

    def withdraw(self, amount):
        if amount <= self.balance + self.credit_limit:
            self.balance -= amount
            return f"Withdrawal of ${amount:.2f} from credit card account successful."
        else:
            return "Insufficient credit limit."


savings_account = SavingsAccount(account_number="SA123", balance=1000.0, interest_rate=0.02)
checking_account = CheckingAccount(account_number="CA456", balance=1500.0, overdraft_limit=500.0)
credit_card_account = CreditCardAccount(account_number="CC789", balance=-200.0, credit_limit=1000.0)

# Using the polymorphic withdraw method with different account types
print("Savings Account:")
print(savings_account.withdraw(500.0))
print(savings_account.display_balance())

print("\nChecking Account:")
print(checking_account.withdraw(200.0))
print(checking_account.display_balance())

print("\nCredit Card Account:")
print(credit_card_account.withdraw(300.0))
print(credit_card_account.display_balance())
# Out:
# Savings Account:
# Withdrawal of $500.00 from savings account successful.
# Account Number: SA123, Balance: $500.00
#
# Checking Account:
# Withdrawal of $200.00 from checking account successful.
# Account Number: CA456, Balance: $1300.00
#
# Credit Card Account:
# Withdrawal of $300.00 from credit card account successful.
# Account Number: CC789, Balance: $-500.00

# %%
# 15. Describe the concept of operator overloading in Python and how it relates to polymorphism. Provide examples using operators like `+` and `*`.

class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        # Overloading the '+' operator
        new_x = self.x + other.x
        new_y = self.y + other.y
        return Point(new_x, new_y)

point1 = Point(1, 2)
point2 = Point(3, 4)

result = point1 + point2

print(result.x, result.y) 
###########################################################

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __mul__(self, scalar):
        # Overloading the '*' operator for scalar multiplication
        new_x = self.x * scalar
        new_y = self.y * scalar
        return Vector(new_x, new_y)


vector = Vector(2, 3)
result = vector * 3

print(result.x, result.y)
# Out:
# 4 6
# 6 9

# %%
# 16. What is dynamic polymorphism, and how is it achieved in Python?
'''
Run-Time Polymorphism (Dynamic Polymorphism):
Also known as method overriding or function overriding.
It involves defining a method in the subclass that is already defined in the parent class.
The appropriate method is chosen at runtime based on the actual type of the object.

Example:
'''
class Animal:
    def make_sound(self):
        pass

class Dog(Animal):
    def make_sound(self):
        return "Woof!"

class Cat(Animal):
    def make_sound(self):
        return "Meow!"

def animal_sound(animal):
    return animal.make_sound()

dog = Dog()
cat = Cat()

print(animal_sound(dog)) 
print(animal_sound(cat))
# Out:
# Woof!
# Meow!

# %%
# 17. Create a Python class hierarchy for employees in a company (e.g., manager, developer, designer) and implement
# polymorphism through a common `calculate_salary()` method.

class Employee:
    def __init__(self, name, role):
        self.name = name
        self.role = role

    def calculate_salary(self):
        raise NotImplementedError("Subclasses must implement the calculate_salary method")


class Manager(Employee):
    def __init__(self, name, team_size):
        super().__init__(name, role="Manager")
        self.team_size = team_size

    def calculate_salary(self):
        # Manager's salary calculation logic
        base_salary = 50000
        team_bonus = self.team_size * 1000
        total_salary = base_salary + team_bonus
        return total_salary


class Developer(Employee):
    def __init__(self, name, programming_language):
        super().__init__(name, role="Developer")
        self.programming_language = programming_language

    def calculate_salary(self):
        # Developer's salary calculation logic
        base_salary = 60000
        language_bonus = 2000 if self.programming_language == "Python" else 1000
        total_salary = base_salary + language_bonus
        return total_salary


class Designer(Employee):
    def __init__(self, name, experience_years):
        super().__init__(name, role="Designer")
        self.experience_years = experience_years

    def calculate_salary(self):
        # Designer's salary calculation logic
        base_salary = 55000
        experience_bonus = self.experience_years * 1000
        total_salary = base_salary + experience_bonus
        return total_salary



manager = Manager(name="John Manager", team_size=8)
developer = Developer(name="Alice Developer", programming_language="Python")
designer = Designer(name="Bob Designer", experience_years=5)

employees = [manager, developer, designer]

for employee in employees:
    print(f"{employee.name} ({employee.role}): Salary - ${employee.calculate_salary()}")
# Out:
# John Manager (Manager): Salary - $58000
# Alice Developer (Developer): Salary - $62000
# Bob Designer (Designer): Salary - $60000

# %%
# 18. Discuss the concept of function pointers and how they can be used to achieve polymorphism in Python.
'''

In Python, the concept of function pointers is not explicit in the same way it is in languages like C or C++. However, Python supports a more flexible
and dynamic approach to achieve polymorphism through functions and objects.

In Python, polymorphism is achieved through a combination of duck typing and the use of callable objects. Duck typing allows objects to be used based
on their behavior rather than their type, and callable objects can be functions, methods, or any object that can be called using parentheses.
'''
class Dog:
    def speak(self):
        return "Woof!"

class Cat:
    def speak(self):
        return "Meow!"

def animal_speak(animal):
    # The function takes any object that has a 'speak' method
    return animal.speak()


dog = Dog()
cat = Cat()


print(animal_speak(dog))  
print(animal_speak(cat))
# Out:
# Woof!
# Meow!

# %%
# 19. Explain the role of interfaces and abstract classes in polymorphism, drawing comparisons between them.
'''
Abstract Classes:
An abstract class is a class that cannot be instantiated on its own. It serves as a blueprint for other classes and can contain both abstract and
concrete methods.
Abstract methods are declared in the abstract class but have no implementation. Subclasses are required to provide concrete implementations for
these methods.
Abstract classes are often used when you want to provide a common base class for a group of related classes, and you want to ensure that certain
methods are implemented in all subclasses.
Abstract classes can have both abstract and concrete methods.
'''
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius

circle = Circle(5)
print(circle.area())
    
'''
Interfaces:
An interface is a collection of method signatures without any implementation. It defines a contract that implementing classes must adhere to.
In Python, there is no explicit interface keyword, but you can use abstract base classes (ABCs) or informal agreements to create interfaces.
Interfaces are used to define a common set of methods that participating classes must implement. They focus on what a class should do rather
than how it should do it.
'''
from abc import ABC, abstractmethod

class Printable(ABC):
    @abstractmethod
    def print(self):
        pass

class Document(Printable):
    def print(self):
        print("Printing document...")

document = Document()
document.print()
# Out:
# 78.5
# Printing document...

# %%
# 20. Create a Python class for a zoo simulation, demonstrating polymorphism with different animal types (e.g., mammals, birds, reptiles) 
# and their behavior (e.g., eating, sleeping, making sounds).

class Animal:
    def __init__(self, name):
        self.name = name

    def eat(self):
        raise NotImplementedError("Subclasses must implement the eat method")

    def sleep(self):
        raise NotImplementedError("Subclasses must implement the sleep method")

    def make_sound(self):
        raise NotImplementedError("Subclasses must implement the make_sound method")


class Mammal(Animal):
    def eat(self):
        return f"{self.name} the mammal is eating."

    def sleep(self):
        return f"{self.name} the mammal is sleeping."

    def make_sound(self):
        return f"{self.name} the mammal is making a sound."


class Bird(Animal):
    def eat(self):
        return f"{self.name} the bird is pecking at seeds."

    def sleep(self):
        return f"{self.name} the bird is perched and sleeping."

    def make_sound(self):
        return f"{self.name} the bird is chirping."


class Reptile(Animal):
    def eat(self):
        return f"{self.name} the reptile is basking in the sun and eating insects."

    def sleep(self):
        return f"{self.name} the reptile is resting in a warm spot."

    def make_sound(self):
        return f"{self.name} the reptile is hissing."


mammal = Mammal(name="Simba")
bird = Bird(name="Kitti")
reptile = Reptile(name="fax")

zoo_animals = [mammal, bird, reptile]

for animal in zoo_animals:
    print(animal.eat())
    print(animal.sleep())
    print(animal.make_sound())
    print()
# Out:
# Simba the mammal is eating.
# Simba the mammal is sleeping.
# Simba the mammal is making a sound.
#
# Kitti the bird is pecking at seeds.
# Kitti the bird is perched and sleeping.
# Kitti the bird is chirping.
#
# fax the reptile is basking in the sun and eating insects.
# fax the reptile is resting in a warm spot.
# fax the reptile is hissing.

# %% [markdown]
# ----------------------------------------------------  Abstraction: --------------------------------------------

# %%
#  1. What is abstraction in Python, and how does it relate to object-oriented programming?

Data abstraction is one of the most essential concepts of Python OOPs which is used to hide irrelevant details from the user and show the details that are relevant to the users.
For example, the readers of geeksforgeeks only know that a writer can write an article on geeksforgeeks, and when it gets published readers can read the articles but the reader is 
not aware of the background process of publishing the article.

A simple example of this can be a car. A car has an accelerator, clutch, and break and we all know that pressing an accelerator will increase the speed of the car and applying the brake
can stop the car but we don’t the internal mechanism of the car and how these functionalities can work this detail hiding is known as data abstraction.

# %%
# 2. Describe the benefits of abstraction in terms of code organization and complexity reduction.
'''
Abstraction offers several benefits in terms of code organization and complexity reduction in software development. Here are key advantages:

Simplifies Understanding:
    Abstraction helps simplify code by focusing on essential features and hiding unnecessary details. Developers can work with high-level concepts, making it easier to understand and reason
    about the codebase.

Modular Design:
    Abstraction encourages a modular design where a complex system is broken down into smaller, independent modules. Each module represents a specific functionality, making it easier to
    develop, test, and maintain isolated parts of the system.

Promotes Reusability:
    Abstracting away implementation details results in the creation of reusable components. These components can be used in different parts of the program or even in entirely different 
    projects, leading to less redundant code and more efficient development.
    
'''

# %%
# 3. Create a Python class called `Shape` with an abstract method `calculate_area()`. Then, create child
# classes (e.g., `Circle`, `Rectangle`) that implement the `calculate_area()` method. Provide an example of using these classes.

from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width


circle = Circle(radius=5)
rectangle = Rectangle(length=4, width=6)

print(f"Area of the Circle: {circle.calculate_area()} square units")
print(f"Area of the Rectangle: {rectangle.calculate_area()} square units")
# Out:
# Area of the Circle: 78.5 square units
# Area of the Rectangle: 24 square units

# %%
# 4. Explain the concept of abstract classes in Python and how they are defined using the `abc` module. Provide an example.

from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

# Attempting to create an instance of the abstract class will raise an error
# shape = Shape()  # Uncommenting this line would raise an error


circle = Circle(radius=5)
rectangle = Rectangle(length=4, width=6)

print(f"Area of the Circle: {circle.calculate_area()} square units")
print(f"Area of the Rectangle: {rectangle.calculate_area()} square units")
# Out:
# Area of the Circle: 78.5 square units
# Area of the Rectangle: 24 square units

# %%
# 5. How do abstract classes differ from regular classes in Python? Discuss their use cases.

# %%
# 6. Create a Python class for a bank account and demonstrate abstraction by hiding the account balance and providing methods to deposit and withdraw funds.

from abc import ABC, abstractmethod

class BankAccount(ABC):
    def __init__(self, account_holder, account_number):
        self.account_holder = account_holder
        self.account_number = account_number
        self._balance = 0  # Starting with a zero balance

    @abstractmethod
    def deposit(self, amount):
        pass

    @abstractmethod
    def withdraw(self, amount):
        pass

    def get_balance(self):
        return self._balance

class SavingsAccount(BankAccount):
    def __init__(self, account_holder, account_number, interest_rate=0.02):
        super().__init__(account_holder, account_number)
        self.interest_rate = interest_rate

    def deposit(self, amount):
        self._balance += amount

    def withdraw(self, amount):
        if amount <= self._balance:
            self._balance -= amount
        else:
            print("Insufficient funds.")

    def add_interest(self):
        self._balance += self._balance * self.interest_rate


savings_account = SavingsAccount(account_holder="Animesh Samanta", account_number="123456789")
print(f"Initial Balance: ${savings_account.get_balance()}")

savings_account.deposit(1000)
print(f"Balance after deposit: ${savings_account.get_balance()}")

savings_account.withdraw(500)
print(f"Balance after withdrawal: ${savings_account.get_balance()}")

savings_account.add_interest()
print(f"Balance after adding interest: ${savings_account.get_balance()}")
# Out:
# Initial Balance: $0
# Balance after deposit: $1000
# Balance after withdrawal: $500
# Balance after adding interest: $510.0

# %%
# 7. Discuss the concept of interface classes in Python and their role in achieving abstraction.

# %%
# 8. Create a Python class hierarchy for animals and implement abstraction by defining common methods (e.g., `eat()`, `sleep()`) in an abstract base class.

from abc import ABC, abstractmethod

class Animal(ABC):
    def __init__(self, name, species):
        self.name = name
        self.species = species

    @abstractmethod
    def make_sound(self):
        pass

    @abstractmethod
    def eat(self):
        pass

    @abstractmethod
    def sleep(self):
        pass

class Dog(Animal):
    def make_sound(self):
        return "Woof!"

    def eat(self):
        return f"{self.name} the dog is eating dog food."

    def sleep(self):
        return f"{self.name} the dog is sleeping in a cozy bed."

class Cat(Animal):
    def make_sound(self):
        return "Meow!"

    def eat(self):
        return f"{self.name} the cat is eating cat food."

    def sleep(self):
        return f"{self.name} the cat is napping in a sunny spot."

class Elephant(Animal):
    def make_sound(self):
        return "Trumpet!"

    def eat(self):
        return f"{self.name} the elephant is enjoying a snack of leaves and fruits."

    def sleep(self):
        return f"{self.name} the elephant is resting under a tree."


dog = Dog(name="Buddy", species="Dog")
cat = Cat(name="Whiskers", species="Cat")
elephant = Elephant(name="Dumbo", species="Elephant")

animals = [dog, cat, elephant]

for animal in animals:
    print(f"{animal.name} ({animal.species}):")
    print(f"Sound: {animal.make_sound()}")
    print(f"Eating: {animal.eat()}")
    print(f"Sleeping: {animal.sleep()}")
    print()
# Out:
# Buddy (Dog):
# Sound: Woof!
# Eating: Buddy the dog is eating dog food.
# Sleeping: Buddy the dog is sleeping in a cozy bed.
#
# Whiskers (Cat):
# Sound: Meow!
# Eating: Whiskers the cat is eating cat food.
# Sleeping: Whiskers the cat is napping in a sunny spot.
#
# Dumbo (Elephant):
# Sound: Trumpet!
# Eating: Dumbo the elephant is enjoying a snack of leaves and fruits.
# Sleeping: Dumbo the elephant is resting under a tree.

# %%
# 9. Explain the significance of encapsulation in achieving abstraction. Provide examples.

'''
Encapsulation is a fundamental concept in object-oriented programming (OOP) that involves bundling the data (attributes) and methods (functions) that operate on the data into a single
unit called a class. Encapsulation facilitates information hiding, where the internal details of a class are hidden from the outside world, and only a well-defined interface is exposed.
This concept is closely related to achieving abstraction in software design.

Hide Implementation Details:
    Encapsulation allows you to hide the internal details of how a class achieves its functionality. The outside world interacts with the class through a set of well-defined methods and
    properties, without needing to know the intricate implementation details.

Promote Abstraction Levels:
    Encapsulation enables the creation of abstract interfaces for classes. The class defines a high-level interface that abstracts away the complexities of its internal workings. 
    This promotes a clear separation between what a class does and how it does it.

Prevent Unauthorized Access:
    By encapsulating data within a class and providing controlled access through methods (getters and setters), encapsulation prevents unauthorized direct access to the internal state
    of an object. This ensures that data integrity is maintained and allows for validation and control over how data is modified.
    
'''

# %%
# 10. What is the purpose of abstract methods, and how do they enforce abstraction in Python classes?
'''
In Python, abstract properties are a way to declare abstract attributes in abstract classes. An abstract property ensures that any concrete subclass must provide an implementation for that property. Abstract properties are part of the broader concept of abstract classes and are defined using the @abstractmethod decorator in conjunction with the property decorator.
'''

from abc import ABC, abstractmethod

class Shape(ABC):
    @property
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self._radius = radius

    @property
    def area(self):
        return 3.14 * self._radius ** 2

class Square(Shape):
    def __init__(self, side):
        self._side = side

    @property
    def area(self):
        return self._side ** 2

# Uncommenting the following lines will result in an error, as Shape is an abstract class
# my_shape = Shape()

# Uncommenting the following lines will result in an error, as Circle and Square do not provide an implementation for the 'area' property
my_circle = Circle(radius=5)
#print(my_circle.area())

my_square = Square(side=4)
#print(my_square.area())

# %%
# 11. Create a Python class for a vehicle system and demonstrate abstraction by defining common methods (e.g., `start()`, `stop()`) in an abstract base class.

from abc import ABC, abstractmethod

class Vehicle(ABC):
    def __init__(self, make, model):
        self.make = make
        self.model = model
        self.is_running = False

    @abstractmethod
    def start(self):
        pass

    @abstractmethod
    def stop(self):
        pass

class Car(Vehicle):
    def start(self):
        if not self.is_running:
            self.is_running = True
            return f"The {self.make} {self.model} is now running."
        else:
            return f"The {self.make} {self.model} is already running."

    def stop(self):
        if self.is_running:
            self.is_running = False
            return f"The {self.make} {self.model} has been stopped."
        else:
            return f"The {self.make} {self.model} is already stopped."

class Motorcycle(Vehicle):
    def start(self):
        if not self.is_running:
            self.is_running = True
            return f"The {self.make} {self.model} motorcycle is now running."
        else:
            return f"The {self.make} {self.model} motorcycle is already running."

    def stop(self):
        if self.is_running:
            self.is_running = False
            return f"The {self.make} {self.model} motorcycle has been stopped."
        else:
            return f"The {self.make} {self.model} motorcycle is already stopped."


car = Car(make="Toyota", model="Camry")
motorcycle = Motorcycle(make="Harley-Davidson", model="Sportster")

print(car.start())
print(motorcycle.start())

print(car.stop())
print(motorcycle.stop())
# Out:
# The Toyota Camry is now running.
# The Harley-Davidson Sportster motorcycle is now running.
# The Toyota Camry has been stopped.
# The Harley-Davidson Sportster motorcycle has been stopped.

# %%
# 12. Describe the use of abstract properties in Python and how they can be employed in abstract classes.
'''

In Python, abstract properties are a way to declare abstract attributes in abstract classes. An abstract property ensures that any concrete subclass must provide an implementation for that property. Abstract properties are part of the broader concept of abstract classes and are defined using the @abstractmethod decorator in conjunction with the property decorator.
'''

from abc import ABC, abstractmethod

class Shape(ABC):
    @property
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self._radius = radius

    @property
    def area(self):
        return 3.14 * self._radius ** 2

class Square(Shape):
    def __init__(self, side):
        self._side = side

    @property
    def area(self):
        return self._side ** 2

# Uncommenting the following lines will result in an error, as Shape is an abstract class
# my_shape = Shape()

# Uncommenting the following lines will result in an error, as Circle and Square do not provide an implementation for the 'area' property
# my_circle = Circle(radius=5)
# my_square = Square(side=4)

# %%
# 13. Create a Python class hierarchy for employees in a company (e.g., manager, developer, designer) and implement
# abstraction by defining a common `get_salary()` method.

from abc import ABC, abstractmethod

class Employee(ABC):
    def __init__(self, name, employee_id):
        self.name = name
        self.employee_id = employee_id

    @abstractmethod
    def get_salary(self):
        pass

class Manager(Employee):
    def __init__(self, name, employee_id, bonus_percentage):
        super().__init__(name, employee_id)
        self.bonus_percentage = bonus_percentage

    def get_salary(self):
        base_salary = 50000  # Assuming a base salary for managers
        bonus_amount = base_salary * (self.bonus_percentage / 100)
        total_salary = base_salary + bonus_amount
        return total_salary

class Developer(Employee):
    def __init__(self, name, employee_id, programming_language):
        super().__init__(name, employee_id)
        self.programming_language = programming_language

    def get_salary(self):
        base_salary = 60000  # Assuming a base salary for developers
        if self.programming_language == "Python":
            bonus_amount = 5000
        else:
            bonus_amount = 0
        total_salary = base_salary + bonus_amount
        return total_salary

class Designer(Employee):
    def __init__(self, name, employee_id, years_of_experience):
        super().__init__(name, employee_id)
        self.years_of_experience = years_of_experience

    def get_salary(self):
        base_salary = 55000  # Assuming a base salary for designers
        experience_bonus = min(self.years_of_experience * 1000, 5000)
        total_salary = base_salary + experience_bonus
        return total_salary

manager = Manager(name="John Doe", employee_id="M001", bonus_percentage=10)
developer = Developer(name="Alice Smith", employee_id="D001", programming_language="Python")
designer = Designer(name="Bob Johnson", employee_id="DS001", years_of_experience=3)

print(f"{manager.name}'s Salary: ${manager.get_salary()}")
print(f"{developer.name}'s Salary: ${developer.get_salary()}")
print(f"{designer.name}'s Salary: ${designer.get_salary()}")
# Out:
# John Doe's Salary: $55000.0
# Alice Smith's Salary: $65000
# Bob Johnson's Salary: $58000

# %%
# 14. Discuss the differences between abstract classes and concrete classes in Python, including their instantiation.

# %%
# 15. Explain the concept of abstract data types (ADTs) and their role in achieving abstraction in Python.

# %%
# 16. Create a Python class for a computer system, demonstrating abstraction by defining common methods (e.g., `power_on()`, `shutdown()`) in an abstract base class.

from abc import ABC, abstractmethod

class ComputerSystem(ABC):
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model
        self.is_powered_on = False

    @abstractmethod
    def power_on(self):
        pass

    @abstractmethod
    def shutdown(self):
        pass

class Desktop(ComputerSystem):
    def power_on(self):
        if not self.is_powered_on:
            self.is_powered_on = True
            return f"The {self.brand} {self.model} desktop is now powered on."
        else:
            return f"The {self.brand} {self.model} desktop is already powered on."

    def shutdown(self):
        if self.is_powered_on:
            self.is_powered_on = False
            return f"The {self.brand} {self.model} desktop has been shut down."
        else:
            return f"The {self.brand} {self.model} desktop is already shut down."

class Laptop(ComputerSystem):
    def power_on(self):
        if not self.is_powered_on:
            self.is_powered_on = True
            return f"The {self.brand} {self.model} laptop is now powered on."
        else:
            return f"The {self.brand} {self.model} laptop is already powered on."

    def shutdown(self):
        if self.is_powered_on:
            self.is_powered_on = False
            return f"The {self.brand} {self.model} laptop has been shut down."
        else:
            return f"The {self.brand} {self.model} laptop is already shut down."


desktop = Desktop(brand="Dell", model="OptiPlex")
laptop = Laptop(brand="HP", model="EliteBook")

print(desktop.power_on())
print(laptop.power_on())

print(desktop.shutdown())
print(laptop.shutdown())
# Out:
# The Dell OptiPlex desktop is now powered on.
# The HP EliteBook laptop is now powered on.
# The Dell OptiPlex desktop has been shut down.
# The HP EliteBook laptop has been shut down.

# %%
# 17. Discuss the benefits of using abstraction in large-scale software development projects.

Complexity Management:
    Abstraction helps manage the complexity of large-scale systems by hiding unnecessary details and focusing on essential concepts. This simplification makes it easier for developers
    to understand, maintain, and extend the codebase.

Code Reusability:
    Abstraction promotes the creation of reusable components and modules. These abstracted components can be employed in different parts of the project, leading to less redundant code 
    and more efficient development.
    
Modular Design:
    Abstraction encourages a modular design where the system is divided into independent, cohesive modules. Each module represents a specific aspect of functionality, making it easier
    to develop, test, and maintain isolated parts of the system.

Consistent Interfaces:
    Abstracting away implementation details results in well-defined and consistent interfaces. This consistency simplifies collaboration among development teams, as they can rely on
    standardized interfaces when integrating different components.

# %%
# 18. Explain how abstraction enhances code reusability and modularity in Python programs.

Abstraction is a fundamental concept in programming that involves simplifying complex systems by modeling classes based on essential features and ignoring unnecessary details. In Python, abstraction enhances code reusability and modularity through several mechanisms:

Encapsulation:
    Abstraction often goes hand in hand with encapsulation. By encapsulating the implementation details within a class and exposing a well-defined interface, abstraction allows you to
    hide the complexity of how a certain functionality is achieved. This encapsulation reduces the chances of unintended interference and enhances code reusability.

Modular Design:
    Abstraction promotes modular design by breaking down a system into smaller, independent modules or classes. Each module is responsible for a specific aspect of functionality, making 
    the codebase more modular and easier to understand.

Reusable Components:
    Abstracting away implementation details results in the creation of reusable components. These components can be used in different parts of the program or even in entirely different
    projects. The ability to reuse well-designed and tested components saves development time and effort.

# %%
# 19. Create a Python class for a library system, implementing abstraction by defining common methods (e.g., `add_book()`, `borrow_book()`) in an abstract base class.

from abc import ABC, abstractmethod

class LibrarySystem(ABC):
    def __init__(self, name):
        self.name = name
        self.books = {}

    @abstractmethod
    def add_book(self, book_title, author):
        pass

    @abstractmethod
    def borrow_book(self, book_title):
        pass

    @abstractmethod
    def return_book(self, book_title):
        pass

class SimpleLibrary(LibrarySystem):
    def add_book(self, book_title, author):
        if book_title not in self.books:
            self.books[book_title] = {"author": author, "available": True}
            return f"Added '{book_title}' by {author} to the library."
        else:
            return f"'{book_title}' already exists in the library."

    def borrow_book(self, book_title):
        if book_title in self.books and self.books[book_title]["available"]:
            self.books[book_title]["available"] = False
            return f"Borrowed '{book_title}' from the library."
        elif book_title in self.books:
            return f"'{book_title}' is currently unavailable."
        else:
            return f"'{book_title}' does not exist in the library."

    def return_book(self, book_title):
        if book_title in self.books and not self.books[book_title]["available"]:
            self.books[book_title]["available"] = True
            return f"Returned '{book_title}' to the library."
        elif book_title in self.books:
            return f"'{book_title}' is already available in the library."
        else:
            return f"'{book_title}' does not exist in the library."


library = SimpleLibrary(name="My Library")

print(library.add_book("The Great Gatsby", "F. Scott Fitzgerald"))
print(library.add_book("To Kill a Mockingbird", "Harper Lee"))

print(library.borrow_book("The Great Gatsby"))
print(library.borrow_book("The Catcher in the Rye"))

print(library.return_book("The Great Gatsby"))
print(library.return_book("The Catcher in the Rye"))
# Out:
# Added 'The Great Gatsby' by F. Scott Fitzgerald to the library.
# Added 'To Kill a Mockingbird' by Harper Lee to the library.
# Borrowed 'The Great Gatsby' from the library.
# 'The Catcher in the Rye' does not exist in the library.
# Returned 'The Great Gatsby' to the library.
# 'The Catcher in the Rye' does not exist in the library.

# %%
# 20. Describe the concept of method abstraction in Python and how it relates to polymorphism.

Method abstraction in Python refers to the idea of defining methods in a way that emphasizes their functionality and behavior without exposing the implementation details. It involves
creating abstract, high-level interfaces for methods, allowing different classes to implement these methods in a way that suits their specific needs.

In Python, method abstraction is closely related to polymorphism—a key concept in object-oriented programming. Polymorphism allows objects of different types to be treated as objects 
of a common type. This enables a single interface to represent a variety of different objects and behaviors

# %% [markdown]
# ------------------------------------------------------  Composition:  -------------------------------------------------------

# %%
# 1. Explain the concept of composition in Python and how it is used to build complex objects from simpler ones.
'''
Composition in Python is a concept in object-oriented programming (OOP) that involves building complex objects by combining or composing simpler objects. It is a way to create relationships between classes where one class contains instances of other classes as components. The composed objects form a part-whole relationship, and the resulting composite object can exhibit behaviors and properties derived from its components.
'''
class Engine:
    def start(self):
        return "Engine started"

    def stop(self):
        return "Engine stopped"

class Wheel:
    def rotate(self):
        return "Wheel rotating"

class Car:
    def __init__(self):
        self.engine = Engine()
        self.wheels = [Wheel() for _ in range(4)]  # Four wheels

    def start(self):
        return f"{self.engine.start()} and {', '.join(w.rotate() for w in self.wheels)}"

    def stop(self):
        return f"{self.engine.stop()} and {', '.join(w.rotate() for w in self.wheels)}"

my_car = Car()
print(my_car.start())
# Out:
# Engine started and Wheel rotating, Wheel rotating, Wheel rotating, Wheel rotating

# %%
# 2. Describe the difference between composition and inheritance in object-oriented programming.

'''
Composition and inheritance are two fundamental concepts in object-oriented programming (OOP) that represent different ways of achieving code reuse and structuring classes. 
Here's a brief overview of the key differences between composition and inheritance:

Composition:
    Building Relationships:
        Composition involves building relationships between classes by creating instances of one class within another. The containing class has components (instances of other classes)
        as its attributes.

    "Has-A" Relationship:
        Composition is often described as a "has-a" relationship. For example, a Car class may "have" an Engine class and Wheel class as its components.
    
    Encapsulation:
        Composition promotes encapsulation by allowing objects to hide their internal details. The contained objects (components) are not exposed directly; instead, they are accessed 
        through well-defined interfaces provided by the containing class.

        
    Flexibility:
        Composition provides more flexibility because you can dynamically change the behavior of a class by altering its composed components. Components can be added, removed, or 
        replaced at runtime.


Inheritance:
    
    Establishing a Hierarchy:
        Inheritance involves creating a hierarchy of classes where a subclass inherits the properties and behaviors of a superclass. The subclass is said to "extend" or "derive from"
        the superclass.

    "Is-A" Relationship:
        Inheritance is often described as an "is-a" relationship. For example, a Dog class may inherit from an Animal class, indicating that a Dog is a specific type of Animal.

        
    Code Reuse:
        Inheritance facilitates code reuse by allowing a subclass to inherit the attributes and methods of a superclass. This promotes a more hierarchical and structured codebase.

    Method Overriding:
        Subclasses can override or extend the methods of the superclass, providing a way to customize or specialize behavior. This supports the concept of polymorphism.
        
'''

# %%
# 3. Create a Python class called `Author` with attributes for name and birthdate. Then, create a `Book` class that contains an instance of `Author`
# as a composition. Provide an example of creating a `Book` object.

class Author:
    def __init__(self, name, birthdate):
        self.name = name
        self.birthdate = birthdate

    def __str__(self):
        return f"Author: {self.name} (Birthdate: {self.birthdate})"

class Book:
    def __init__(self, title, genre, author, publication_year):
        self.title = title
        self.genre = genre
        self.author = author  # Composition: Book has an Author
        self.publication_year = publication_year

    def __str__(self):
        return f"Book: {self.title} ({self.genre})\n{self.author}\nPublished in {self.publication_year}"


author_jane_doe = Author(name="Jane Doe", birthdate="January 1, 1980")

book1 = Book(title="Python Programming", genre="Programming", author=author_jane_doe, publication_year=2022)
book2 = Book(title="Data Science Essentials", genre="Data Science", author=author_jane_doe, publication_year=2021)

print(book1)

print("\n",book2)
# Out:
# Book: Python Programming (Programming)
# Author: Jane Doe (Birthdate: January 1, 1980)
# Published in 2022
#
#  Book: Data Science Essentials (Data Science)
# Author: Jane Doe (Birthdate: January 1, 1980)
# Published in 2021

# %%
# 4. Discuss the benefits of using composition over inheritance in Python, especially in terms of code flexibility and reusability.

'''
Flexibility:
    Composition allows you to create more flexible and adaptable class structures. With composition, you can dynamically change the behavior of a class by altering its composed 
    components, providing greater flexibility than a fixed inheritance hierarchy.

Improved Code Reusability:
    Composition facilitates better code reusability by allowing you to reuse classes in different contexts. Instead of relying on an inheritance hierarchy, you can compose objects from
    existing classes, making it easier to leverage existing code in various scenarios

Dynamic Composition at Runtime:
    With composition, you can dynamically compose objects at runtime based on specific requirements. This dynamic composition allows you to create variations of objects without the
    need for a predefined class hierarchy.
'''

# %%
# 5. How can you implement composition in Python classes? Provide examples of using composition to create complex objects.
'''
In Python, composition can be implemented by including instances of other classes as attributes within a class. This allows you to build complex objects by composing simpler ones. Let's go through a simple example to illustrate how composition can be implemented in Python:
'''

class Engine:
    def start(self):
        return "Engine started"

    def stop(self):
        return "Engine stopped"

class Wheel:
    def rotate(self):
        return "Wheel rotating"

class Car:
    def __init__(self, engine, wheels):
        self.engine = engine
        self.wheels = wheels

    def start(self):
        return f"{self.engine.start()} and {', '.join(w.rotate() for w in self.wheels)}"

    def stop(self):
        return f"{self.engine.stop()} and {', '.join(w.rotate() for w in self.wheels)}"


my_engine = Engine()
my_wheels = [Wheel() for _ in range(4)]  # Creating 4 wheels for a car


my_car = Car(engine=my_engine, wheels=my_wheels)


print(my_car.start())  
print(my_car.stop())
# Out:
# Engine started and Wheel rotating, Wheel rotating, Wheel rotating, Wheel rotating
# Engine stopped and Wheel rotating, Wheel rotating, Wheel rotating, Wheel rotating

# %%
# 6. Create a Python class hierarchy for a music player system, using composition to represent playlists and songs.

class MusicPlayerSystem:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model
        self.playlists = []

    def add_playlist(self, playlist):
        self.playlists.append(playlist)

    def play(self):
        return "Music player is playing."

    def pause(self):
        return "Music player is paused."

    def __str__(self):
        return f"Music Player System: {self.brand} {self.model}"

class Playlist:
    def __init__(self, name):
        self.name = name
        self.songs = []

    def add_song(self, song):
        self.songs.append(song)

    def play(self):
        return f"Playlist '{self.name}' is playing."

    def __str__(self):
        return f"Playlist: {self.name}"

class Song:
    def __init__(self, title, artist, duration):
        self.title = title
        self.artist = artist
        self.duration = duration

    def play(self):
        return f"Playing '{self.title}' by {self.artist} ({self.duration} seconds)."

    def __str__(self):
        return f"Song: {self.title} by {self.artist}"


my_music_player = MusicPlayerSystem(brand="Sony", model="Walkman")

playlist1 = Playlist(name="Favorites")
playlist2 = Playlist(name="MoodSwing")

song1 = Song(title="Shape of You", artist="Ed Sheeran", duration=240)
song2 = Song(title="Someone Like You", artist="Adele", duration=300)
song3 = Song(title="Perfect", artist="Ed Sheeran", duration=270)

playlist1.add_song(song1)
playlist1.add_song(song2)

playlist2.add_song(song2)
playlist2.add_song(song3)

my_music_player.add_playlist(playlist1)
my_music_player.add_playlist(playlist2)

# Print music player information
print(my_music_player)

# Print playlists and songs
for playlist in my_music_player.playlists:
    print(playlist)
    for song in playlist.songs:
        print(f"  {song}")

# Play a song
print("\n" + my_music_player.play())
print(playlist1.play())
print(song1.play())

# Pause the music player
print("\n" + my_music_player.pause())
# Out:
# Music Player System: Sony Walkman
# Playlist: Favorites
#   Song: Shape of You by Ed Sheeran
#   Song: Someone Like You by Adele
# Playlist: MoodSwing
#   Song: Someone Like You by Adele
#   Song: Perfect by Ed Sheeran
#
# Music player is playing.
# Playlist 'Favorites' is playing.
# Playing 'Shape of You' by Ed Sheeran (240 seconds).
#
# Music player is paused.

# %%
# 7. Explain the concept of "has-a" relationships in composition and how it helps design software systems.
'''
The concept of "has-a" relationships in composition is a fundamental principle in object-oriented programming (OOP) that describes how one class can be composed of or contain another
class as part of its internal structure. This relationship is often expressed through the use of instance variables or attributes, and it signifies that an object of one class "has"
another class as one of its components.
'''

# %%
# 8. Create a Python class for a computer system, using composition to represent components like CPU, RAM, and storage devices.

class ComputerSystem:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model
        self.cpu = CPU()
        self.ram = RAM()
        self.storage = Storage()

    def power_on(self):
        return "Computer system is powering on."

    def power_off(self):
        return "Computer system is powering off."

    def __str__(self):
        return f"Computer System: {self.brand} {self.model}"

class CPU:
    def __init__(self, brand="Intel", model="i5"):
        self.brand = brand
        self.model = model

    def process_data(self):
        return "CPU is processing data."

class RAM:
    def __init__(self, capacity_gb=8):
        self.capacity_gb = capacity_gb

    def read_data(self):
        return "RAM is reading data."

    def write_data(self):
        return "RAM is writing data."

class Storage:
    def __init__(self, capacity_gb=512):
        self.capacity_gb = capacity_gb

    def read_data(self):
        return "Storage is reading data."

    def write_data(self):
        return "Storage is writing data."


my_computer = ComputerSystem(brand="Dell", model="XPS 15")

print(my_computer)
print(my_computer.power_on())
print(my_computer.cpu.process_data())
print(my_computer.ram.read_data())
print(my_computer.storage.read_data())
print(my_computer.power_off())
# Out:
# Computer System: Dell XPS 15
# Computer system is powering on.
# CPU is processing data.
# RAM is reading data.
# Storage is reading data.
# Computer system is powering off.

# %%
# 9. Describe the concept of "delegation" in composition and how it simplifies the design of complex systems.

'''
Delegation in the context of object-oriented programming and composition refers to the practice of one object handing over responsibility for a particular task to another object.
Instead of a class inheriting behavior from a superclass, it relies on the collaboration with other classes to achieve functionality. Delegation is a powerful concept that simplifies
the design of complex systems in several ways:

Separation of Concerns:
    Delegation promotes a clear separation of concerns by assigning specific responsibilities to different objects. Each object is responsible for a well-defined task, making the
    codebase more modular and easier to understand.

Code Reusability:
    Delegation facilitates code reuse by allowing objects to be reused in different contexts. Rather than inheriting behavior, a class can delegate tasks to other classes, promoting a 
    more flexible and reusable design.
    
Flexibility and Adaptability:
    Delegation allows for greater flexibility and adaptability in the system. Objects can be easily replaced or modified without affecting the rest of the system, as long as they adhere
    to the same interface.
    
Dynamic Behavior:
    The behavior of a class can be dynamically changed by switching the delegate at runtime. This dynamic nature allows for more adaptable and extensible systems without the need for
    extensive modifications to existing code.
    
Reduced Coupling:
    Delegation can help reduce tight coupling between classes. Instead of relying on a fixed hierarchy of classes, objects can interact through well-defined interfaces, minimizing
    dependencies and making the system more maintainable.

'''

# %%
# 10. Create a Python class for a car, using composition to represent components like the engine, wheels, and transmission.

class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.engine = Engine()
        self.transmission = Transmission()
        self.wheels = [Wheel() for _ in range(4)]

    def start(self):
        return "Car is starting."

    def drive(self):
        return "Car is in motion."

    def stop(self):
        return "Car has stopped."

    def __str__(self):
        return f"Car: {self.year} {self.make} {self.model}"

class Engine:
    def start(self):
        return "Engine is starting."

    def stop(self):
        return "Engine has stopped."

class Transmission:
    def shift(self):
        return "Transmission is shifting gears."

class Wheel:
    def rotate(self):
        return "Wheel is rotating."


my_car = Car(make="Toyota", model="Camry", year=2022)

print(my_car)
print(my_car.start())
print(my_car.drive())
print(my_car.stop())

# Accessing components
print(my_car.engine.start())
print(my_car.transmission.shift())
for wheel in my_car.wheels:
    print(wheel.rotate())
# Out:
# Car: 2022 Toyota Camry
# Car is starting.
# Car is in motion.
# Car has stopped.
# Engine is starting.
# Transmission is shifting gears.
# Wheel is rotating.
# Wheel is rotating.
# Wheel is rotating.
# Wheel is rotating.

# %%
# 11. How can you encapsulate and hide the details of composed objects in Python classes to maintain abstraction?
'''
Private Attributes:

Use private attributes in your classes to restrict direct access to the internal details of composed objects. In Python, attributes and methods with names starting with a double underscore (__) are considered private.
'''
class MyClass:
    def __init__(self):
        self.__internal_object = ComposedObject()


'''
Property Decorators:

Use property decorators to create getter and setter methods for accessing and modifying the composed objects. This allows you to control access and add logic as needed.
'''
class MyClass:
    def __init__(self):
        self._internal_object = ComposedObject()

    @property
    def internal_object(self):
        return self._internal_object

    @internal_object.setter
    def internal_object(self, value):
        # Add logic or validation if needed
        self._internal_object = value

        
'''
Interface or Abstract Base Class (ABC):

Define an interface or abstract base class that represents the common behavior expected from composed objects. Ensure that the composed objects adhere to this interface.
'''
from abc import ABC, abstractmethod

class ComposedObjectInterface(ABC):
    @abstractmethod
    def common_method(self):
        pass

class ComposedObject(ComposedObjectInterface):
    def common_method(self):
        # Implementation of the common method
        pass

class MyClass:
    def __init__(self):
        self._internal_object = ComposedObject()

# %%
# 12. Create a Python class for a university course, using composition to represent students, instructors, and course materials.

class UniversityCourse:
    def __init__(self, name, code):
        self.name = name
        self.code = code
        self.students = []
        self.instructor = None
        self.course_materials = []

    def add_student(self, student):
        self.students.append(student)

    def set_instructor(self, instructor):
        self.instructor = instructor

    def add_course_material(self, material):
        self.course_materials.append(material)

    def __str__(self):
        return f"University Course: {self.name} ({self.code})"

class Student:
    def __init__(self, student_id, name):
        self.student_id = student_id
        self.name = name

    def __str__(self):
        return f"Student: {self.name} (ID: {self.student_id})"

class Instructor:
    def __init__(self, instructor_id, name):
        self.instructor_id = instructor_id
        self.name = name

    def __str__(self):
        return f"Instructor: {self.name} (ID: {self.instructor_id})"

class CourseMaterial:
    def __init__(self, title, content):
        self.title = title
        self.content = content

    def __str__(self):
        return f"Course Material: {self.title}"


course = UniversityCourse(name="Introduction to Computer Science", code="CS101")

student1 = Student(student_id="S001", name="Animesh")
student2 = Student(student_id="S002", name="Akash")

instructor = Instructor(instructor_id="I001", name="Dr. Avijit")

material1 = CourseMaterial(title="Week 1 Lecture Notes", content="Introduction to Python")
material2 = CourseMaterial(title="Assignment Guidelines", content="Data Structures and Algorithms")

course.add_student(student1)
course.add_student(student2)
course.set_instructor(instructor)
course.add_course_material(material1)
course.add_course_material(material2)

print(course)

# Print students, instructor, and course materials
print("Students:")
for student in course.students:
    print(f"  {student}")

print("Instructor:")
print(f"  {course.instructor}")

print("Course Materials:")
for material in course.course_materials:
    print(f"  {material}")
# Out:
# University Course: Introduction to Computer Science (CS101)
# Students:
#   Student: Animesh (ID: S001)
#   Student: Akash (ID: S002)
# Instructor:
#   Instructor: Dr. Avijit (ID: I001)
# Course Materials:
#   Course Material: Week 1 Lecture Notes
#   Course Material: Assignment Guidelines

# %%
# 13. Discuss the challenges and drawbacks of composition, such as increased complexity and potential for tight coupling between objects.

'''
While composition in object-oriented programming offers several advantages, it also comes with its own set of challenges and drawbacks. Here are some of the key challenges associated
with composition:

Increased Complexity:
    Composition can lead to increased complexity, especially in large systems where there are numerous composed objects. Managing relationships and interactions between these objects 
    can become intricate and harder to understand.
    
Learning Curve:
    Understanding the composition structure and relationships between objects may pose a learning curve for developers, especially those who are new to the codebase. This can hinder 
    maintainability and collaboration.
    
Boilerplate Code:
    In some cases, implementing composition can result in additional boilerplate code, especially when dealing with delegation of methods and properties. This can make the code less
    concise and more error-prone.
    
Performance Overhead:
    There may be a slight performance overhead associated with the use of composition, especially if there are many small objects involved. Each method call or property access involves 
    an additional layer of indirection.
    
'''

# %%
# 14. Create a Python class hierarchy for a restaurant system, using composition to represent menus, dishes, and ingredients.

class Restaurant:
    def __init__(self, name):
        self.name = name
        self.menus = []

    def add_menu(self, menu):
        self.menus.append(menu)

    def __str__(self):
        return f"Restaurant: {self.name}"

class Menu:
    def __init__(self, name):
        self.name = name
        self.dishes = []

    def add_dish(self, dish):
        self.dishes.append(dish)

    def __str__(self):
        return f"Menu: {self.name}"

class Dish:
    def __init__(self, name, price):
        self.name = name
        self.price = price
        self.ingredients = []

    def add_ingredient(self, ingredient, quantity):
        self.ingredients.append({"ingredient": ingredient, "quantity": quantity})

    def __str__(self):
        return f"Dish: {self.name} | Price: ${self.price}"

class Ingredient:
    def __init__(self, name):
        self.name = name

    def __str__(self):
        return f"Ingredient: {self.name}"


restaurant = Restaurant(name="Gourmet Delight")

menu1 = Menu(name="Breakfast Menu")
menu2 = Menu(name="Dinner Menu")

dish1 = Dish(name="Pancakes", price=8.99)
dish1.add_ingredient(Ingredient(name="Flour"), quantity=1)
dish1.add_ingredient(Ingredient(name="Eggs"), quantity=2)
dish1.add_ingredient(Ingredient(name="Milk"), quantity=1)

dish2 = Dish(name="Grilled Salmon", price=19.99)
dish2.add_ingredient(Ingredient(name="Salmon"), quantity=1)
dish2.add_ingredient(Ingredient(name="Lemon"), quantity=1)
dish2.add_ingredient(Ingredient(name="Herbs"), quantity=1)

menu1.add_dish(dish1)
menu2.add_dish(dish2)

restaurant.add_menu(menu1)
restaurant.add_menu(menu2)

print(restaurant)

# Print menus and dishes
for menu in restaurant.menus:
    print(menu)
    for dish in menu.dishes:
        print(f"  {dish}")
        for ingredient in dish.ingredients:
            print(f"    {ingredient['quantity']} {ingredient['ingredient']}")
# Out:
# Restaurant: Gourmet Delight
# Menu: Breakfast Menu
#   Dish: Pancakes | Price: $8.99
#     1 Ingredient: Flour
#     2 Ingredient: Eggs
#     1 Ingredient: Milk
# Menu: Dinner Menu
#   Dish: Grilled Salmon | Price: $19.99
#     1 Ingredient: Salmon
#     1 Ingredient: Lemon
#     1 Ingredient: Herbs

# %%
# 15. Explain how composition enhances code maintainability and modularity in Python programs.

'''
Composition is a fundamental principle in object-oriented programming (OOP) that involves combining simple objects to create more complex ones. In Python, composition enhances code 
maintainability and modularity through several mechanisms:

Encapsulation:
    Composition allows you to encapsulate the implementation details of individual objects. Each object exposes a well-defined interface, and the internal details are hidden.
    This encapsulation reduces the complexity seen by other parts of the program, making it easier to understand and maintain.
    
Modularity:
    Composition encourages the creation of modular and reusable components. You can design classes with specific responsibilities, and these classes can be reused in different contexts.
    Modular components are easier to test, understand, and maintain. Changes in one module don't necessarily affect others, promoting a more maintainable codebase.
    
Code Reusability:
    With composition, you can create small, focused classes that can be reused in various combinations to build different functionalities.
    Reusable components save development time and effort, as you can leverage existing code instead of reinventing the wheel.
    
'''

# %%
# 16. Create a Python class for a computer game character, using composition to represent attributes like weapons, armor, and inventory.

class Character:
    def __init__(self, name, health=100):
        self.name = name
        self.health = health
        self.weapon = None
        self.armor = None
        self.inventory = []

    def equip_weapon(self, weapon):
        self.weapon = weapon

    def equip_armor(self, armor):
        self.armor = armor

    def add_to_inventory(self, item):
        self.inventory.append(item)

    def attack(self, target):
        if self.weapon:
            damage = self.weapon.attack()
            target.take_damage(damage)
            return f"{self.name} attacks {target.name} with {self.weapon.name} and deals {damage} damage."
        else:
            return f"{self.name} attacks {target.name} with bare hands, but has no weapon."

    def take_damage(self, damage):
        if self.armor:
            reduced_damage = self.armor.reduce_damage(damage)
            self.health -= reduced_damage
            return f"{self.name} takes {reduced_damage} damage after armor reduction."
        else:
            self.health -= damage
            return f"{self.name} takes {damage} damage."

    def __str__(self):
        return f"Character: {self.name} | Health: {self.health}"

class Weapon:
    def __init__(self, name, damage):
        self.name = name
        self.damage = damage

    def attack(self):
        return self.damage

    def __str__(self):
        return f"Weapon: {self.name} | Damage: {self.damage}"

class Armor:
    def __init__(self, name, defense):
        self.name = name
        self.defense = defense

    def reduce_damage(self, incoming_damage):
        return max(0, incoming_damage - self.defense)

    def __str__(self):
        return f"Armor: {self.name} | Defense: {self.defense}"


player = Character(name="Hero", health=150)
enemy = Character(name="Enemy", health=100)

sword = Weapon(name="Sword", damage=20)
shield = Armor(name="Shield", defense=10)

player.equip_weapon(sword)
player.equip_armor(shield)

print(player)
print(enemy)

print(player.attack(enemy))
print(enemy)

print(enemy.attack(player))
print(player)


potion = "Health Potion"
player.add_to_inventory(potion)
print(f"{player.name}'s Inventory: {player.inventory}")
# Out:
# Character: Hero | Health: 150
# Character: Enemy | Health: 100
# Hero attacks Enemy with Sword and deals 20 damage.
# Character: Enemy | Health: 80
# Enemy attacks Hero with bare hands, but has no weapon.
# Character: Hero | Health: 150
# Hero's Inventory: ['Health Potion']

# %%
# 17. Describe the concept of "aggregation" in composition and how it differs from simple composition.

'''
Aggregation and simple composition are both concepts related to object-oriented programming, specifically in terms of how objects are related and combined. Let's delve into each concept:

Simple Composition:
    In simple composition, an object is composed of one or more other objects.
    The composed object has a "has-a" relationship with its parts. For example, a Car class may have instances of Engine, Wheel, and Chassis as its components.
    The lifecycle of the parts is tied to the lifecycle of the whole. If the Car is destroyed, its components are usually destroyed as well.
    Simple composition implies a strong relationship between the whole and its parts, and typically, the parts are considered integral to the whole.

    
Aggregation:
    Aggregation is a specific form of association, representing a relationship where one class is a part of another class but can exist independently.
    In aggregation, the "has-a" relationship still exists, but the parts can exist independently of the whole. For instance, consider a University class that has a collection of
    Department objects. A Department can exist even if the University is not present.
    
    The lifecycle of aggregated objects is not necessarily tied to the lifecycle of the whole. Destroying the University does not necessarily mean destroying all its Department objects.
    Aggregation implies a weaker relationship between the whole and its parts compared to simple composition
    
'''

# %%
# 18. Create a Python class for a house, using composition to represent rooms, furniture, and appliances.

class House:
    def __init__(self, address):
        self.address = address
        self.rooms = []

    def add_room(self, room):
        self.rooms.append(room)

    def __str__(self):
        return f"House at {self.address}"

class Room:
    def __init__(self, name, area):
        self.name = name
        self.area = area
        self.furniture = []
        self.appliances = []

    def add_furniture(self, furniture):
        self.furniture.append(furniture)

    def add_appliance(self, appliance):
        self.appliances.append(appliance)

    def __str__(self):
        return f"Room: {self.name} (Area: {self.area} sq. ft.)"

class Furniture:
    def __init__(self, name):
        self.name = name

    def __str__(self):
        return f"Furniture: {self.name}"

class Appliance:
    def __init__(self, name):
        self.name = name

    def __str__(self):
        return f"Appliance: {self.name}"

living_room = Room(name="Living Room", area=300)
kitchen = Room(name="Kitchen", area=200)
bedroom = Room(name="Bedroom", area=250)

sofa = Furniture(name="Sofa")
dining_table = Furniture(name="Dining Table")
refrigerator = Appliance(name="Refrigerator")
oven = Appliance(name="Oven")

living_room.add_furniture(sofa)
#living_room.add_appliance(television)

kitchen.add_furniture(dining_table)
kitchen.add_appliance(oven)

#bedroom.add_furniture(Bed(name="King-sized Bed"))

my_house = House(address="123 Main Street")
my_house.add_room(living_room)
my_house.add_room(kitchen)
my_house.add_room(bedroom)

print(my_house)
for room in my_house.rooms:
    print(room)
    for item in room.furniture + room.appliances:
        print(f"  {item}")
# Out:
# House at 123 Main Street
# Room: Living Room (Area: 300 sq. ft.)
#   Furniture: Sofa
# Room: Kitchen (Area: 200 sq. ft.)
#   Furniture: Dining Table
#   Appliance: Oven
# Room: Bedroom (Area: 250 sq. ft.)

# %%
# 19. How can you achieve flexibility in composed objects by allowing them to be replaced or modified dynamically at runtime?

'''
To achieve flexibility in composed objects by allowing them to be replaced or modified dynamically at runtime, you can use a combination of design patterns and principles. Here are some 
approaches:

Use Interfaces and Abstract Classes:
    Define interfaces or abstract classes to represent the common behavior of the objects.
    Composed objects should implement these interfaces or inherit from these abstract classes.
    This allows you to interchange objects dynamically as long as they adhere to the common interface.

Dependency Injection:
    Inject dependencies into objects rather than hard-coding them within the object.
    This allows you to replace or modify dependencies dynamically at runtime.
    Dependency injection frameworks can help manage and inject dependencies.

Strategy Pattern:
    Define a family of algorithms, encapsulate each algorithm, and make them interchangeable.
    Composed objects can have a strategy interface, and different strategies can be swapped at runtime.

Decorator Pattern:
    Decorators provide a flexible alternative to subclassing for extending functionality dynamically.
    Compose objects with decorators that add or modify behavior at runtime.
    Decorators can be added or removed dynamically, providing flexibility.
    
    
'''

# %%
#  20. Create a Python class for a social media application, using composition to represent users, posts, and comments.

class User:
    def __init__(self, username, email):
        self.username = username
        self.email = email
        self.posts = []

    def create_post(self, content):
        post = Post(content=content, author=self)
        self.posts.append(post)
        return post

    def __str__(self):
        return f"User: {self.username}"

class Post:
    def __init__(self, content, author):
        self.content = content
        self.author = author
        self.comments = []

    def add_comment(self, user, text):
        comment = Comment(user=user, text=text)
        self.comments.append(comment)
        return comment

    def __str__(self):
        return f"Post by {self.author.username}: {self.content}"

class Comment:
    def __init__(self, user, text):
        self.user = user
        self.text = text

    def __str__(self):
        return f"Comment by {self.user.username}: {self.text}"

user1 = User(username="Animesh", email="animesh123@gmail.com")
user2 = User(username="Akash", email="akash123@gmail..com")

post1 = user1.create_post(content="Hello, world!")
post2 = user2.create_post(content="This is a great day!")

comment1 = post1.add_comment(user=user2, text="Nice post!")
comment2 = post2.add_comment(user=user1, text="Thanks,Akash!")

print(user1)
print(user2)


print(post1)
for comment in post1.comments:
    print(comment)

print(post2)
for comment in post2.comments:
    print(comment)
# Out:
# User: Animesh
# User: Akash
# Post by Animesh: Hello, world!
# Comment by Akash: Nice post!
# Post by Akash: This is a great day!
# Comment by Animesh: Thanks,Akash!
